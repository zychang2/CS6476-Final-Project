# %% [markdown]
# ### Necessary imports

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import cv2
from IPython.display import Video
from torchvision.io import read_video, read_video_timestamps
import csv
import av
import json

import tensorflow as tf

# %% [markdown]
# ### Append video dataset paths and JSON path

# %%
train_dir = os.path.normpath(os.getcwd() + "/../Video processing" + os.sep + "video_small" + os.sep + "train")
val_dir = os.path.normpath(os.getcwd() +  "/../Video processing" + os.sep + "video_small" + os.sep + "val")
sys.path.append(train_dir)
sys.path.append(val_dir)

# %%
path_to_data = os.path.normpath(os.getcwd() + "/../Video processing" + os.sep + "video_small/")

# %%
info_json_path = os.path.join(os.getcwd() + "/../Video processing" + os.sep + "video_small" + os.sep + "smaller_transition_times.json")
info_json = json.load(open(info_json_path))

# %%
test_video = "train/oops/25 Best Trampoline Fail Nominees - FailArmy Hall of Fame (July 2017)23.mp4"
test_key = "25 Best Trampoline Fail Nominees - FailArmy Hall of Fame (July 2017)23"
video_path = os.path.join(path_to_data, test_video)
Video(video_path, embed=True, width=600)
# Out:
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
test_video = "train/no_oops/Armpit Wax - Fails You Missed (April 2018) _ 201825.mp4"
test_key = "Armpit Wax - Fails You Missed (April 2018) _ 201825"
video_path = os.path.join(path_to_data, test_video)
Video(video_path, embed=True, width=600)
# Out:
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
def get_label_time(key, info_json):
  times = info_json[key]['t']
  if min(times) < 0:
    return -1
  else:
    return np.mean(times)
# from DLM - batch (dict): batch of data batch['obs'].shape = (B, T, Obs_dim)
#                     and batch['actions'].shape = (B, T, Action_dim)

def trim_video(video_tensor, video_timestamps, time_limit):
  video_tensor = np.array(video_tensor)
  video_timestamps = np.array(video_timestamps)
  video_tensor = video_tensor[video_timestamps < time_limit]
  video_timestamps = video_timestamps[video_timestamps < time_limit]
  return video_tensor, video_timestamps

def subsample_video(video_tensor, video_timestamps, video_fps, hz, num_frames=25):
  fps_ratio = round(video_fps / hz)
  frame_samples = [round(x * fps_ratio) for x in range(num_frames)]
  video_tensor = np.array(video_tensor)
  video_timestamps = np.array(video_timestamps)
  if video_tensor.shape[0] <= frame_samples[-1]:
    frame_samples = frame_samples[:-1]
  # print(frame_samples)
  # video_tensor = video_tensor[::fps_ratio]
  new_video_tensor = video_tensor[frame_samples]
  # video_timestamps = video_timestamps[::fps_ratio]
  new_video_timestamps = video_timestamps[frame_samples]
  if new_video_tensor.shape[0] > num_frames:
    new_video_tensor = new_video_tensor[:num_frames]
    new_video_timestamps = new_video_timestamps[:num_frames]
  elif new_video_tensor.shape[0] == num_frames-1:
    new_video_tensor = np.append(new_video_tensor, np.array([video_tensor[-1]]), axis=0)
    new_video_timestamps = np.append(new_video_timestamps, np.array([video_timestamps[-1]]), axis=0)
  else:
    print(new_video_tensor.shape[0])
  return new_video_tensor, new_video_timestamps

def match_labels_to_frames(video_tensor, video_timestamps, time):
  if time < 0:
    time = 100000000000000
  # else:
  #   time_ms = time
  labels = np.where(np.array(video_timestamps) < time, 0, 1)
  batch = {'frames': video_tensor, 'labels': labels}
  return batch

def grayscale_video(video_tensor):
  video_tensor = np.array(video_tensor)
  video_tensor = np.array(tf.image.rgb_to_grayscale(video_tensor))
  # video_tensor = video_tensor.squeeze()
  return video_tensor

def reshape_video(video_tensor, size):
  video_tensor = np.array(video_tensor)
  n, d1, d2, c = video_tensor.shape
  if d1 < d2:
    y = d1
    x = d2
    v_offset = 0
    h_offset = int((x/2) - (y/2))
  else:
    y = d2
    x = d1
    v_offset = int((x/2) - (y/2))
    h_offset = 0
  video_tensor = tf.image.crop_to_bounding_box(video_tensor, v_offset, h_offset, y, y)
  video_tensor = tf.image.resize(video_tensor, size)
  video_tensor = np.array(video_tensor)
  return video_tensor

# %%
def save_video(video_dict, path, video_name):
  if not os.path.exists(path):
    os.makedirs(path)
  video_tensor = video_dict['frames']
  labels = video_dict['labels']
  # Save Images
  for i in range(video_tensor.shape[0]):
    image = video_tensor[i]
    save_path = path + '/' + video_name + '_' + str(i).zfill(2) + '.jpg'
    # print(save_path)
    cv2.imwrite(save_path, image)
  # Save Labels
  labels_path = path + '/' + video_name + '_labels.csv'
  with open(labels_path, 'a', newline='') as csvfile:
    label_writer = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    label_writer.writerow(labels)

# %%
def process_video(video_name, video_path, info_json, time_limit=5.5, shape=(240, 240), hz=5):
  # Read video from path and get tensor and timestamps
  v_tensor, _, fps_info = read_video(video_path, pts_unit='sec')
  v_timestamps, video_fps = read_video_timestamps(video_path, pts_unit='sec')
  # Get label change time
  label_time = get_label_time(video_name, info_json)
  # Process video
  v_tensor, v_timestamps = subsample_video(v_tensor, v_timestamps, video_fps, hz, num_frames=25) # Subsample
  # v_tensor, v_timestamps = trim_video(v_tensor, v_timestamps, time_limit) # Trim
  if v_tensor.shape[0] != 25:
    raise Exception("Video " + video_name + " is not 25 frames long! It is " + str(v_tensor.shape[0]) + " frames long.")
  v_tensor = grayscale_video(v_tensor) # Grayscale
  v_tensor = reshape_video(v_tensor, shape) # Reshape
  # print(v_tensor.shape)
  frames_and_labels = match_labels_to_frames(v_tensor, v_timestamps, label_time) # Get labels
  return frames_and_labels

# %%
def process_dataset(data_path, new_data_path, video_json):
  count = 0
  for video in video_json.keys():
    # Get path for video in json
    category = video_json[video]['category']
    label = video_json[video]['label']
    video_path = os.path.join(data_path, category, label, video) + '.mp4'
    save_path = os.path.join(new_data_path, category)
    if os.path.isfile(save_path + '/' + video + '_labels.csv'):
      count += 1
      print("Video", count, "already exists. Skipping.")
      continue
    # if label == 'no_oops':
    #   continue
    # Convert video into tensor
    frames_and_labels = process_video(video, video_path, video_json, time_limit=5, shape=(240, 240))
    # Save tensor to processed images and label csv in new data path
    save_video(frames_and_labels, save_path, video)
    count += 1
    print("Saved video", count, "out of", len(video_json.keys()), "-", video)

# %%
data_path = path_to_data
new_data_path = os.path.normpath(os.getcwd() + os.sep + "video_proc/")
# new_data_path = '/content/temp/video_proc_ii'
json_file = 'smaller_transition_times.json'
video_json = info_json

# %%
process_dataset(data_path, new_data_path, video_json)
# Out:
# 25
# Saved video 1 out of 1255 - 25 Best Trampoline Fail Nominees - FailArmy Hall of Fame (July 2017)18
# 25
# Saved video 2 out of 1255 - 28 Best Skateboard Fail Nominees - FailArmy Hall of Fame (August 2017)18
# 25
# Saved video 3 out of 1255 - 29 Best Work Fail Nominees - FailArmy Hall of Fame (August 2017)1
# 25
# Saved video 4 out of 1255 - 34 Workout Fail Nominees - FailArmy Hall Of Fame (April 2017)8
# 25
# Saved video 5 out of 1255 - A Boatload of Fails - Throwback Fails (November 2017) _ FailArmy12
# 25
# Saved video 6 out of 1255 - A Boatload of Fails - Throwback Fails (November 2017) _ FailArmy95
# 25
# Saved video 7 out of 1255 - American Fails (July 2017) _ FailArmy37
# 25
# Saved video 8 out of 1255 - Animals Can Be Jerks! (June 2018) _ FailArmy6
# 25
# Saved video 9 out of 1255 - Armpit Wax - Fails You Missed (April 2018) _ 201825
# 25
# Saved video 10 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy14
# 25
# Saved video 11 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy17
# 25
# Saved video 12 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy22
# 25
# Saved video 13 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy42
# 25
# Saved video 14 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy5
# 25
# Saved video 15 out of 1255 - Basketball Fails - March Madness! (March 2017) _ FailArmy25
# 25
# Saved video 16 out of 1255 - Basketball Fails - March Madness! (March 2017) _ FailArmy5
# 25
# Saved video 17 out of 1255 - Batter Up - America's Past Time Fails (August 2018) _ FailArmy8
# 25
# Saved video 18 out of 1255 - Bedtime - Mattress Fails11
# 25
# Saved video 19 out of 1255 - Bedtime - Mattress Fails29
# 25
# Saved video 20 out of 1255 - Bedtime - Mattress Fails30
# 25
# Saved video 21 out of 1255 - Bedtime - Mattress Fails43
# 25
# Saved video 22 out of 1255 - Best Fail of the Week - Bad Kitty! (April 2018) _ FailArmy10
# 25
# Saved video 23 out of 1255 - Best Fails of the Month - Driving Me Crazy! (January 2018) _ FailArmy35
# 25
# Saved video 24 out of 1255 - Best Fails of the Month - Driving Me Crazy! (January 2018) _ FailArmy56
# 25
# Saved video 25 out of 1255 - Best Fails of the Month - Is This Regulation Size (March 2018) _ FailArmy14
# 25
# Saved video 26 out of 1255 - Best Fails of the Month April 2016 _ FailArmy39
# 25
# Saved video 27 out of 1255 - Best Fails of the Month February 2016 _ 'Babe, You're Actually Crazy!' FailArmy50
# 25
# Saved video 28 out of 1255 - Best Fails of the Week - My Life Flashed Before My Eyes! (January 2018) _ FailArmy2
# 25
# Saved video 29 out of 1255 - Best Fails of the Week - No Baseball Inside! (December 2017) _ FailArmy32
# 25
# Saved video 30 out of 1255 - Best Fails of the Week - This Is Poppin' (January 2018) _ FailArmy29
# 25
# Saved video 31 out of 1255 - Best Fails of the Week - Watch Out!  (March 2018) _ FailArmy30
# 25
# Saved video 32 out of 1255 - Best Fails of the Week 1 April 2016 _ 'You Knew That Was Going To Happen!' FailArmy32
# 25
# Saved video 33 out of 1255 - Best Fails of the Week 1 March 2016 _ 'WTF Was that!' by FailArmy14
# 25
# Saved video 34 out of 1255 - Best Fails of the Week 1 May 2016 _ 'That Squirrel Just Attacked Me! by FailArmy82
# 25
# Saved video 35 out of 1255 - Best Fails of the Week 2 April 2016 _ 'I Knew That Was a Bad Idea' by FailArmy54
# 25
# Saved video 36 out of 1255 - Best Fails of the Week 2 May 2016 _ FailArmy 'That Was An Epic Fail Sam'52
# 25
# Saved video 37 out of 1255 - Best Fails of the Week 4 March 2016 _ 'Not Today!!' FailArmy33
# 25
# Saved video 38 out of 1255 - Best Fails of the Year - Part 2 (2018) _ FailArmy28
# 25
# Saved video 39 out of 1255 - Best Fails of the Year 2016 (So Far) _ FailArmy Fail Compilation128
# Saved video 40 out of 1255 - Best Fails of the Year 2016 (So Far) _ FailArmy Fail Compilation96
# 25
# Saved video 41 out of 1255 - Best Fails of the Year 2016 (So Far) _ FailArmy Fail Compilation98
# 25
# Saved video 42 out of 1255 - Best Fails of the Year 2017 - Part 2 (December 2017) _ FailArmy94
# 25
# Saved video 43 out of 1255 - Best Fails of the Year 2017 - Part 2 (December 2017) _ FailArmy97
# 25
# Saved video 44 out of 1255 - Best Fails of the Year 2018 (So Far) _ FailArmy64
# 25
# Saved video 45 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy13
# 25
# Saved video 46 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy25
# 25
# Saved video 47 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy36
# 25
# Saved video 48 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy46
# 25
# Saved video 49 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy5
# 25
# Saved video 50 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy6
# 25
# Saved video 51 out of 1255 - Big Air - Soaring with Style! (September 2017) _ FailArmy38
# 25
# Saved video 52 out of 1255 - Bikes vs. Scooters - War of the Wheels (January 2017) _ FailArmy63
# 25
# Saved video 53 out of 1255 - Brain Freeze Is Real! - Fails of the Month (June 2017) _ FailArmy18
# 25
# Saved video 54 out of 1255 - Carnival of Excess (March 2019) _ FailArmy24
# 25
# Saved video 55 out of 1255 - Carnival of Excess (March 2019) _ FailArmy47
# 25
# Saved video 56 out of 1255 - Cats vs. Birds - FailArmy Versus (October 2017) _ FailArmy22
# 25
# Saved video 57 out of 1255 - Cats vs. Birds - FailArmy Versus (October 2017) _ FailArmy25
# 25
# Saved video 58 out of 1255 - Cats vs. Birds - FailArmy Versus (October 2017) _ FailArmy32
# 25
# Saved video 59 out of 1255 - Cats vs. Birds - FailArmy Versus (October 2017) _ FailArmy5
# 25
# Saved video 60 out of 1255 - Cats vs. Birds - FailArmy Versus (October 2017) _ FailArmy8
# 25
# Saved video 61 out of 1255 - Christmas Fails (December 2016) _ FailArmy23
# 25
# Saved video 62 out of 1255 - Christmas Fails (December 2016) _ FailArmy24
# 25
# Saved video 63 out of 1255 - Christmas Fails (December 2016) _ FailArmy39
# 25
# Saved video 64 out of 1255 - Close Calls & Near Misses Compilation _ FailArmy 201627
# 25
# Saved video 65 out of 1255 - Close Calls & Near Misses Compilation _ FailArmy 201629
# 25
# Saved video 66 out of 1255 - Close Calls & Near Misses Compilation _ FailArmy 201643
# Saved video 67 out of 1255 - Close Calls & Near Misses Compilation _ FailArmy 201644
# 25
# Saved video 68 out of 1255 - Close Calls & Near Misses Compilation _ FailArmy 201650
# 25
# Saved video 69 out of 1255 - Close Calls - Best of the Year 2017 _ FailArmy1
# 25
# Saved video 70 out of 1255 - Commuting Fails - Crazy Drivers! (January 2018) _ FailArmy12
# 25
# Saved video 71 out of 1255 - Commuting Fails - Crazy Drivers! (January 2018) _ FailArmy18
# 25
# Saved video 72 out of 1255 - Commuting Fails - Crazy Drivers! (January 2018) _ FailArmy29
# 25
# Saved video 73 out of 1255 - Commuting Fails - Crazy Drivers! (January 2018) _ FailArmy43
# 25
# Saved video 74 out of 1255 - Cut it Out - Knife Fails (October 2018) _ FailArmy30
# 25
# Saved video 75 out of 1255 - Dive Right In - Diving Fails (October 2018) _ FailArmy45
# 25
# Saved video 76 out of 1255 - Doggone It! - Fails You Missed #23 (December 2017) _ FailArmy53
# 25
# Saved video 77 out of 1255 - Don't Drive In Russia - Fails You Missed #19 (December 2017) _ FailArmy25
# 25
# Saved video 78 out of 1255 - Don't Drive In Russia - Fails You Missed #19 (December 2017) _ FailArmy89
# 25
# Saved video 79 out of 1255 - Don't Rock the Boat! - Throwback Fails (February 2018) _ FailArmy21
# Saved video 80 out of 1255 - Double Fails Compilation _ 'Double Trouble' By FailArmy 201659
# 25
# Saved video 81 out of 1255 - Dress To Impress - Lookin' Good! (October 2017) _ FailArmy1
# 25
# Saved video 82 out of 1255 - Dress To Impress - Lookin' Good! (October 2017) _ FailArmy39
# 25
# Saved video 83 out of 1255 - Dressed For Success (July 2018) _ FailArmy28
# 25
# Saved video 84 out of 1255 - Dummy Dogs _ 'Dog Fails' By FailArmy23
# 25
# Saved video 85 out of 1255 - Dummy Dogs _ 'Dog Fails' By FailArmy7
# 25
# Saved video 86 out of 1255 - Dunking Over Kids - Best Fails Of The Week (April 2018) _ FailArmy35
# 25
# Saved video 87 out of 1255 - Fail Higher, Faster - Mountain Fails (April 2017) _ FailArmy41
# 25
# Saved video 88 out of 1255 - Fail Olympics _ 'FAIL-YMPICS PART 2' by FailArmy 201633
# 25
# Saved video 89 out of 1255 - FailArmy After Dark - It's Party Time (ep. 1)98
# Saved video 90 out of 1255 - FailArmy After Dark - Let The Tuna Go! (Ep. 5)104
# 25
# Saved video 91 out of 1255 - FailArmy After Dark - Let The Tuna Go! (Ep. 5)109
# 25
# Saved video 92 out of 1255 - FailArmy After Dark - Let The Tuna Go! (Ep. 5)110
# 25
# Saved video 93 out of 1255 - FailArmy After Dark - Let The Tuna Go! (Ep. 5)155
# 25
# Saved video 94 out of 1255 - FailArmy After Dark - Let The Tuna Go! (Ep. 5)73
# 25
# Saved video 95 out of 1255 - FailArmy After Dark - Let's Get Crazy!  (Ep. 4)181
# 25
# Saved video 96 out of 1255 - FailArmy After Dark - Let's Get Crazy!  (Ep. 4)47
# 25
# Saved video 97 out of 1255 - FailArmy After Dark - Sliding Into The Weekend (Ep. 11)143
# 25
# Saved video 98 out of 1255 - FailArmy After Dark - Sliding Into The Weekend (Ep. 11)42
# 25
# Saved video 99 out of 1255 - FailArmy After Dark - That's Going To Cost You  (Ep. 9)112
# 25
# Saved video 100 out of 1255 - FailArmy After Dark - That's Going To Cost You  (Ep. 9)116
# 25
# Saved video 101 out of 1255 - FailArmy After Dark - That's Going To Cost You  (Ep. 9)133
# 25
# Saved video 102 out of 1255 - FailArmy After Dark - That's Going To Cost You  (Ep. 9)79
# Saved video 103 out of 1255 - FailArmy Presents - Funny Pet Fails by The Pet Collective24
# 25
# Saved video 104 out of 1255 - FailArmy Presents - Funny Pet Fails by The Pet Collective33
# 25
# Saved video 105 out of 1255 - FailArmy Presents - Funny Pet Fails by The Pet Collective37
# 25
# Saved video 106 out of 1255 - FailArmy Presents - Funny Pet Fails by The Pet Collective39
# 25
# Saved video 107 out of 1255 - FailArmy Presents - People Are Awesome - Fails VS. Wins #149
# 25
# Saved video 108 out of 1255 - FailArmy Presents - People are Awesome _ Epic Wins Compilation39
# 25
# Saved video 109 out of 1255 - FailArmy Presents - People are Awesome _ Epic Wins Compilation5
# 25
# Saved video 110 out of 1255 - FailArmy Presents - People are Awesome _ Epic Wins Compilation59
# 25
# Saved video 111 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #215
# 25
# Saved video 112 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #233
# 25
# Saved video 113 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #244
# 25
# Saved video 114 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #40
# 25
# Saved video 115 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #417
# 25
# Saved video 116 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #419
# 25
# Saved video 117 out of 1255 - FailArmy Presents - People Are Awesome! Wins vs. Fails #49
# 25
# Saved video 118 out of 1255 - FailArmy Reanimated - Pineapple Head (March 2018)0
# 25
# Saved video 119 out of 1255 - FailArmy Reanimated - Pineapple Head (March 2018)16
# 25
# Saved video 120 out of 1255 - FailArmy Reanimated - Pineapple Head (March 2018)18
# 25
# Saved video 121 out of 1255 - FailArmy Reanimated - Pineapple Head (March 2018)3
# 25
# Saved video 122 out of 1255 - FailArmy Throwbacks - Hold On Tight! (May 2017)72
# 25
# Saved video 123 out of 1255 - FailArmy Throwbacks - Hold On Tight! (May 2017)82
# 25
# Saved video 124 out of 1255 - FailArmy Versus - City Fails vs. Country Fails (July 2017)43
# 25
# Saved video 125 out of 1255 - FailArmy Versus - Reptiles Vs. Mammals (February 2018) _ FailArmy12
# 25
# Saved video 126 out of 1255 - FailArmy Versus - Reptiles Vs. Mammals (February 2018) _ FailArmy34
# 25
# Saved video 127 out of 1255 - FailArmy's Halloween Spooktacular! (October 2017) _ FailArmy33
# 25
# Saved video 128 out of 1255 - FailArmy's Halloween Spooktacular! (October 2017) _ FailArmy4
# 25
# Saved video 129 out of 1255 - FailFactory - Gravity Always Wins (February 2019) _ FailArmy83
# 25
# Saved video 130 out of 1255 - Fails Like Teen Spirit (February 2018) _ FailArmy39
# 25
# Saved video 131 out of 1255 - Fails of Summer - Baseball and Softball Fails _ FailArmy1
# 25
# Saved video 132 out of 1255 - Fails of Summer - Baseball and Softball Fails _ FailArmy16
# 25
# Saved video 133 out of 1255 - Fails of Summer - Baseball and Softball Fails _ FailArmy37
# 25
# Saved video 134 out of 1255 - Fails of the Month - Get Ready To Laugh (April 2017)1
# 25
# Saved video 135 out of 1255 - Fails of the Month October 2016 _ FailArmy21
# 25
# Saved video 136 out of 1255 - Fails of the Week - Big Air, Bigger Fails! (March 2017) _ FailArmy24
# 25
# Saved video 137 out of 1255 - Fails of the Week - Bridesmaid Ruins Wedding (June 2017)23
# 25
# Saved video 138 out of 1255 - Fails of the Week - Bridesmaid Ruins Wedding (June 2017)57
# 25
# Saved video 139 out of 1255 - Fails of the Week - Whoa baby! (February 2017) _ FailArmy29
# 25
# Saved video 140 out of 1255 - Fails of the Week - Yes We Did (January 2017) _ FailArmy26
# 25
# Saved video 141 out of 1255 - Fails of the Week 1 November 2016 _ FailArmy31
# 25
# Saved video 142 out of 1255 - Fails of the Week 2 November 2016 _ FailArmy38
# 25
# Saved video 143 out of 1255 - Fails of the Week 2 November 2016 _ FailArmy56
# 25
# Saved video 144 out of 1255 - Fails of the Week 3 (October 2016) _ FailArmy18
# 25
# Saved video 145 out of 1255 - Fails You Missed #24 - Dangerous Animals (January 2018) _ FailArmy83
# 25
# Saved video 146 out of 1255 - Fails You Missed #27 - Didn't See That Coming (January 2018) _ FailArmy16
# 25
# Saved video 147 out of 1255 - Fails You Missed #27 - Didn't See That Coming (January 2018) _ FailArmy62
# 25
# Saved video 148 out of 1255 - Fails You Missed #27 - Didn't See That Coming (January 2018) _ FailArmy68
# 25
# Saved video 149 out of 1255 - Fails You Missed - Did That Girl Fart (March 2018) _ FailArmy101
# 25
# Saved video 150 out of 1255 - Fails You Missed - Did That Girl Fart (March 2018) _ FailArmy37
# 25
# Saved video 151 out of 1255 - Fails You Missed - Did That Girl Fart (March 2018) _ FailArmy53
# Saved video 152 out of 1255 - Fails You Missed - Did That Girl Fart (March 2018) _ FailArmy54
# 25
# Saved video 153 out of 1255 - Fails You Missed - Did That Girl Fart (March 2018) _ FailArmy68
# 25
# Saved video 154 out of 1255 - Fails You Missed - Did That Girl Fart (March 2018) _ FailArmy76
# 25
# Saved video 155 out of 1255 - Fails You Missed - Flexin' On A Lexus! (February 2018)10
# 25
# Saved video 156 out of 1255 - Fails You Missed - Flexin' On A Lexus! (February 2018)45
# 25
# Saved video 157 out of 1255 - Fails You Missed - Is That A Snake (February 2018) _ FailArmy25
# 25
# Saved video 158 out of 1255 - Fails You Missed - Some Pranks Never Get Old (March 2018) _ FailArmy15
# 25
# Saved video 159 out of 1255 - Fails You Missed - Toilet Or Bust! (March 2018) _ FailArmy73
# 25
# Saved video 160 out of 1255 - Fails You Missed - Waiting For Summer! (March 2018) _ FailArmy117
# 25
# Saved video 161 out of 1255 - Farmers Only (March 2019) _ FailArmy34
# 25
# Saved video 162 out of 1255 - Feline Fails - Cat Got Your Tongue (July 2018) _ FailArmy27
# 25
# Saved video 163 out of 1255 - Feline Fails - Cat Got Your Tongue (July 2018) _ FailArmy34
# 25
# Saved video 164 out of 1255 - Fly Higher, Fail Harder - Drone Takedowns (November 2016) _ FailArmy38
# 25
# Saved video 165 out of 1255 - Football Vs. Football (Soccer) _ Fails Compilation by FailArmy41
# 25
# Saved video 166 out of 1255 - Freaky Phobias - Don't Get Scared! (September 2017) _ FailArmy30
# 25
# Saved video 167 out of 1255 - Fun Size Fails - Miniature Fails (June 2017)48
# 25
# Saved video 168 out of 1255 - Fun Size Fails - Miniature Fails (June 2017)9
# 25
# Saved video 169 out of 1255 - Funniest and Craziest Driving Fails _ Worst Drivers Ever by FailArmy39
# 25
# Saved video 170 out of 1255 - Funniest Mom Fails _ Happy Mother's Day from FailArmy50
# 25
# Saved video 171 out of 1255 - Funniest Mom Fails _ Happy Mother's Day from FailArmy68
# 25
# Saved video 172 out of 1255 - Funny and Weird Weather Fails Compilation 2016 _ Best Nature Fails by FailArmy33
# 25
# Saved video 173 out of 1255 - Funny and Weird Weather Fails Compilation 2016 _ Best Nature Fails by FailArmy5
# 25
# Saved video 174 out of 1255 - Funny Animal Fails _ 2016 Animal Compilation from FailArmy20
# 25
# Saved video 175 out of 1255 - Funny Animal Fails _ 2016 Animal Compilation from FailArmy44
# 25
# Saved video 176 out of 1255 - Funny Celebration Fails - Let's get the party started! (May 2017)0
# 25
# Saved video 177 out of 1255 - Funny Celebration Fails - Let's get the party started! (May 2017)35
# 25
# Saved video 178 out of 1255 - Funny Celebration Fails - Let's get the party started! (May 2017)42
# 25
# Saved video 179 out of 1255 - Funny Dad Fails (June 2017)28
# 25
# Saved video 180 out of 1255 - Funny Dad Fails (June 2017)3
# 25
# Saved video 181 out of 1255 - Funny Dad Fails (June 2017)31
# 25
# Saved video 182 out of 1255 - Funny Dad Fails (June 2017)51
# 25
# Saved video 183 out of 1255 - Funny Farm, Cowgirl and Redneck Fails Compilation _ By FailArmy35
# 25
# Saved video 184 out of 1255 - Funny Farm, Cowgirl and Redneck Fails Compilation _ By FailArmy41
# 25
# Saved video 185 out of 1255 - Funny Food and Cooking Fails by FailArmy 201663
# 25
# Saved video 186 out of 1255 - Funny Goats - Screaming Is Optional (March 2017) _ FailArmy13
# 25
# Saved video 187 out of 1255 - Funny Goats - Screaming Is Optional (March 2017) _ FailArmy19
# 25
# Saved video 188 out of 1255 - Funny Goats - Screaming Is Optional (March 2017) _ FailArmy42
# 25
# Saved video 189 out of 1255 - Funny Goats - Screaming Is Optional (March 2017) _ FailArmy45
# 25
# Saved video 190 out of 1255 - Funny Goats - Screaming Is Optional (March 2017) _ FailArmy46
# 25
# Saved video 191 out of 1255 - Funny Goats - Screaming Is Optional (March 2017) _ FailArmy7
# 25
# Saved video 192 out of 1255 - Funny Pet Fails - Lock The Doggy Door! (August 2017) _ FailArmy13
# 25
# Saved video 193 out of 1255 - Funny Pet Fails - Lock The Doggy Door! (August 2017) _ FailArmy26
# 25
# Saved video 194 out of 1255 - Funny Pet Fails - Lock The Doggy Door! (August 2017) _ FailArmy42
# 25
# Saved video 195 out of 1255 - Funny Spring Loaded & Trampoline Fails Compilation _ By FailArmy25
# 25
# Saved video 196 out of 1255 - Game On - Let's Play a Game (May 2019) _ FailArmy29
# 25
# Saved video 197 out of 1255 - Get A New Hobby!! (August 2017) _ FailArmy1
# 25
# Saved video 198 out of 1255 - Get off the Stage - Stage Fails51
# 25
# Saved video 199 out of 1255 - Getting Away From Me Fails (November 2017 _ FailArmy55
# 25
# Saved video 200 out of 1255 - Getting Away From Me Fails (November 2017 _ FailArmy9
# 25
# Saved video 201 out of 1255 - Go Faster, Or Fail! - Throwback Fails (January 2018) _ FailArmy22
# 25
# Saved video 202 out of 1255 - Go Faster, Or Fail! - Throwback Fails (January 2018) _ FailArmy45
# 25
# Saved video 203 out of 1255 - Grass Is Always Greener - Get Off My Lawn! (July 2018) _ FailArmy12
# 25
# Saved video 204 out of 1255 - Hilarious Cat Fails (April 2017)31
# 25
# Saved video 205 out of 1255 - Hilarious Farm Animal Fails (January 2017) _ FailArmy45
# 25
# Saved video 206 out of 1255 - Hilarious Redneck Fails (November 2017) _ FailArmy22
# 25
# Saved video 207 out of 1255 - Hilarious Summer vs. Winter Fails (June 2017) _ FailArmy1
# 25
# Saved video 208 out of 1255 - I Caught A Big Crab! - Throwback Fails (December 2017) _ FailArmy43
# 25
# Saved video 209 out of 1255 - In the Face Fails - That hurt! (August 2017) _ FailArmy41
# 25
# Saved video 210 out of 1255 - Instant Karma Fails - Best of the Year 2017 _ FailArmy1
# 25
# Saved video 211 out of 1255 - Instant Karma Fails - Best of the Year 2017 _ FailArmy31
# 25
# Saved video 212 out of 1255 - Instant Karma Fails - Best of the Year 2017 _ FailArmy38
# 25
# Saved video 213 out of 1255 - Instant Karma Fails - It's Payback Time (December 2016) _ FailArmy1
# 25
# Saved video 214 out of 1255 - International Fails From Around The World! (January 2018) _ FailArmy26
# 25
# Saved video 215 out of 1255 - It's a Jungle Out There! - Wild Animal Fails (November 2017) _ FailArmy21
# 25
# Saved video 216 out of 1255 - It's a Jungle Out There! - Wild Animal Fails (November 2017) _ FailArmy45
# 25
# Saved video 217 out of 1255 - It's Dangerous Outside - Stay Inside (April 2018)  _ FailArmy1
# 25
# Saved video 218 out of 1255 - Just Grow Up! - Act Your Age Fails (July 2017) _ FailArmy23
# 25
# Saved video 219 out of 1255 - Keep It Going, Keep It Going! - Best Fails of the Month (September 2017) _ FailArmy10
# 25
# Saved video 220 out of 1255 - Keep It Going, Keep It Going! - Best Fails of the Month (September 2017) _ FailArmy2
# 25
# Saved video 221 out of 1255 - Laughing Cameraman - Best Laughs Ever! (January 2017) _ FailArmy51
# 25
# Saved video 222 out of 1255 - Let's Get Cheesy - Fails of the Week22
# 25
# Saved video 223 out of 1255 - Living on the Edge - Send It! (November 2018) _ FailArmy9
# 25
# Saved video 224 out of 1255 - Look At Me Like A Boss! - Fails You Missed #14 _ FailArmy116
# 25
# Saved video 225 out of 1255 - Look At Me Like A Boss! - Fails You Missed #14 _ FailArmy35
# 25
# Saved video 226 out of 1255 - Look At Me Like A Boss! - Fails You Missed #14 _ FailArmy60
# 25
# Saved video 227 out of 1255 - Look Out Below - Throwback Thursday (October 2017) _ FailArmy13
# 25
# Saved video 228 out of 1255 - Look Out Below - Throwback Thursday (October 2017) _ FailArmy42
# 25
# Saved video 229 out of 1255 - Look Out For That Bush - Fails of the Week (June 2017) _ FailArmy21
# 25
# Saved video 230 out of 1255 - Look Out For That Bush - Fails of the Week (June 2017) _ FailArmy42
# 25
# Saved video 231 out of 1255 - Moose vs. Hammer! - Fails You Missed #20 (December 2017) _ FailArmy3
# 25
# Saved video 232 out of 1255 - Moose vs. Hammer! - Fails You Missed #20 (December 2017) _ FailArmy59
# 25
# Saved video 233 out of 1255 - My Twig and Berries - Cup Check (February 2019) _ FailArmy43
# 25
# Saved video 234 out of 1255 - My Twig and Berries - Cup Check (February 2019) _ FailArmy44
# 25
# Saved video 235 out of 1255 - Nobody Believed Me! - Fails You Missed #15 _ FailArmy56
# 25
# Saved video 236 out of 1255 - Nobody Believed Me! - Fails You Missed #15 _ FailArmy89
# 25
# Saved video 237 out of 1255 - Nobody Believed Me! - Fails You Missed #15 _ FailArmy93
# 25
# Saved video 238 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy105
# 25
# Saved video 239 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy130
# 25
# Saved video 240 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy133
# 25
# Saved video 241 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy139
# 25
# Saved video 242 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy71
# Saved video 243 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy78
# 25
# Saved video 244 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy86
# 25
# Saved video 245 out of 1255 - Not in the House!  Fails You Missed #13 _ FailArmy95
# Saved video 246 out of 1255 - Ode to America _ Funny 4th of July and Redneck Fails  by FailArmy49
# 25
# Saved video 247 out of 1255 - Polar Vortex Problems35
# 25
# Saved video 248 out of 1255 - Premature Celebrations - Confidence Is Key (March 2018) _ FailArmy0
# 25
# Saved video 249 out of 1255 - Premature Celebrations - Confidence Is Key (March 2018) _ FailArmy14
# 25
# Saved video 250 out of 1255 - Premature Celebrations - Confidence Is Key (March 2018) _ FailArmy3
# 25
# Saved video 251 out of 1255 - Public Transportation is a Nightmare (October 2018) _ FailArmy10
# 25
# Saved video 252 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)10
# 25
# Saved video 253 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)36
# 25
# Saved video 254 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)41
# 25
# Saved video 255 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)45
# 25
# Saved video 256 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)46
# 25
# Saved video 257 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)5
# 25
# Saved video 258 out of 1255 - Put It In Reverse! 😂 - Fails of the Week (July 2017)52
# 25
# Saved video 259 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy10
# 25
# Saved video 260 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy28
# 25
# Saved video 261 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy32
# 25
# Saved video 262 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy41
# 25
# Saved video 263 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy58
# 25
# Saved video 264 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy6
# 25
# Saved video 265 out of 1255 - Recording for Duty - Epic Pranks (February 2019) _ FailArmy79
# 25
# Saved video 266 out of 1255 - Relationship Fails - It's The Heartbreak Hotel (February 2018) _ FailArmy18
# 25
# Saved video 267 out of 1255 - Relationship Fails - It's The Heartbreak Hotel (February 2018) _ FailArmy27
# 25
# Saved video 268 out of 1255 - Relationship Fails - It's The Heartbreak Hotel (February 2018) _ FailArmy39
# 25
# Saved video 269 out of 1255 - Rural vs. Urban Fails (August 2018) _ FailArmy12
# 25
# Saved video 270 out of 1255 - Rural vs. Urban Fails (August 2018) _ FailArmy20
# 25
# Saved video 271 out of 1255 - Russians vs. Rednecks - FailArmy Versus21
# 25
# Saved video 272 out of 1255 - Scaredy Cats _ Pranks and Scare Fails Compilation _ FailArmy 201637
# 25
# Saved video 273 out of 1255 - Shattered Expectations - Fails of the Week (March 2019) _ FailArmy26
# 25
# Saved video 274 out of 1255 - Shattered Expectations - Fails of the Week (March 2019) _ FailArmy38
# 25
# Saved video 275 out of 1255 - She's Not Going To Make It! - Throwback Thursday (September 2017) _ FailArmy1
# 25
# Saved video 276 out of 1255 - Sled Dead Redemption - Fails of the Week _ FailArmy47
# 25
# Saved video 277 out of 1255 - Speeding Into The Weekend - Throwback Fails (January 2018) _ FailArmy65
# 25
# Saved video 278 out of 1255 - Spring Got Sprung - Spring into Action (April 2018) _ FailArmy18
# 25
# Saved video 279 out of 1255 - Spring Got Sprung - Spring into Action (April 2018) _ FailArmy2
# 25
# Saved video 280 out of 1255 - Spring Got Sprung - Spring into Action (April 2018) _ FailArmy6
# 25
# Saved video 281 out of 1255 - Spring is Here (March 2019) _ FailArmy36
# 25
# Saved video 282 out of 1255 - Sticks vs. Stones - FailArmy Versus (September 2017) _ FailArmy24
# 25
# Saved video 283 out of 1255 - Sticks vs. Stones - FailArmy Versus (September 2017) _ FailArmy30
# 25
# Saved video 284 out of 1255 - Stop Tripping - Fails of the Month (August 2017) _ FailArmy1
# 25
# Saved video 285 out of 1255 - Tetherball to the Face - Fails of the Week (March 2019) _ FailArmy14
# 25
# Saved video 286 out of 1255 - Tetherball to the Face - Fails of the Week (March 2019) _ FailArmy31
# 25
# Saved video 287 out of 1255 - Tetherball to the Face - Fails of the Week (March 2019) _ FailArmy8
# 25
# Saved video 288 out of 1255 - The Best 29 Fall Fails - FailArmy Hall of Fame (November 2017)34
# 25
# Saved video 289 out of 1255 - The Best Fail Reactions - Now That's Funny! (September 2017) _ FailArmy33
# 25
# Saved video 290 out of 1255 - The Best Fail Reactions - Now That's Funny! (September 2017) _ FailArmy34
# 25
# Saved video 291 out of 1255 - The Dirtbike Bail of Doom - Fails of the Week (April 2018) _ FailArmy33
# 25
# Saved video 292 out of 1255 - The Drone of Doom - Throwback Thursday (October 2017) _ FailArmy14
# 25
# Saved video 293 out of 1255 - The First 10 Million _ A Thank You Fail Montage by FailArmy58
# 25
# Saved video 294 out of 1255 - The Slide of Doom - Fails of the Week _ FailArmy4
# 25
# Saved video 295 out of 1255 - The Slide of Doom - Fails of the Week _ FailArmy44
# 25
# Saved video 296 out of 1255 - The Top 27 Underwater Fails - FailArmy Hall of Fame (October 2017)1
# 25
# Saved video 297 out of 1255 - This Dog is Trippin - Fails of the Week (October 2018) _ FailArmy33
# 25
# Saved video 298 out of 1255 - This is Why I'm Broke - Expensive Technology Fails58
# 25
# Saved video 299 out of 1255 - Throwback Fails - Face Paint Required! (March 2018) _ FailArmy19
# 25
# Saved video 300 out of 1255 - Throwback Fails - Makeup Tutorial Optional (March 2018) _ FailArmy19
# 25
# Saved video 301 out of 1255 - Throwback Fails - Makeup Tutorial Optional (March 2018) _ FailArmy32
# 25
# Saved video 302 out of 1255 - Throwback Fails - Ready, Set, Fail! (March 2018) _ FailArmy46
# 25
# Saved video 303 out of 1255 - Throwback Fails - Ready, Set, Fail! (March 2018) _ FailArmy55
# 25
# Saved video 304 out of 1255 - Throwback Fails - Show Us Your Stuff! (February 2018) _ FailArmy26
# 25
# Saved video 305 out of 1255 - Throwback Thursday - Are My Teeth OK (May 2017)28
# 25
# Saved video 306 out of 1255 - Throwback Thursday - Try and stay balanced! (April 2017)27
# 25
# Saved video 307 out of 1255 - Throwback Thursday - Try and stay balanced! (April 2017)30
# 25
# Saved video 308 out of 1255 - Throwback Thursday - Try and stay balanced! (April 2017)34
# 25
# Saved video 309 out of 1255 - Throwback Thursday - Watch Out For That!! (April 2017)90
# 25
# Saved video 310 out of 1255 - Throwback Thursday - Watch Out For That!! (April 2017)94
# 25
# Saved video 311 out of 1255 - Throwback Thursday Fails - Here Goes Nothing (April 2017) _ FailArmy53
# 25
# Saved video 312 out of 1255 - Throwback Thursday Fails - Here Goes Nothing (April 2017) _ FailArmy76
# 25
# Saved video 313 out of 1255 - Throwback Thursday Fails - It's Hard Not To Laugh (April 2017)27
# 25
# Saved video 314 out of 1255 - Throwback Thursday Fails - This Water's Gross!! _ FailArmy115
# Saved video 315 out of 1255 - Throwback Thursday Fails - This Water's Gross!! _ FailArmy6
# 25
# Saved video 316 out of 1255 - Throwback Thursday Fails - Try Not to Laugh! (March 2017) _ FailArmy35
# 25
# Saved video 317 out of 1255 - Throwback Thursday Fails - Try Not to Laugh! (March 2017) _ FailArmy94
# 25
# Saved video 318 out of 1255 - Trust Fail - Fails of the Week (December 2018) _ FailArmy19
# 25
# Saved video 319 out of 1255 - Try Not to Flunk - Back to School Fails (August 2018) _ FailArmy5
# 25
# Saved video 320 out of 1255 - Try Not to React - The Fail is Written on Your Face (August 2018) _ FailArmy0
# 25
# Saved video 321 out of 1255 - Try Not to React - The Fail is Written on Your Face (August 2018) _ FailArmy13
# 25
# Saved video 322 out of 1255 - Ultimate Bad Friends - Best of the Year 2017 _ FailArmy1
# 25
# Saved video 323 out of 1255 - Ultimate Fails Compilation 2016 - Part 1 (December 2016) _ FailArmy36
# 25
# Saved video 324 out of 1255 - Ultimate Fails Compilation 2016 - Part 1 (December 2016) _ FailArmy94
# 25
# Saved video 325 out of 1255 - Valentine's Day Fails Compilation _ Salute to Forever Alone by FailArmy19
# 25
# Saved video 326 out of 1255 - Vanity Flair - Expensive Fails (November 2016) _ FailArmy57
# 25
# Saved video 327 out of 1255 - Virtual Reality Freakout - Fails of the Week (November 2018) _ FailArmy33
# 25
# Saved video 328 out of 1255 - VR Fails Are Real - Fails You Missed #25 (January 2018) _ FailArmy72
# 25
# Saved video 329 out of 1255 - Wait, Wait... Throw It!! - Fails of the Week (August 2017) _ FailArmy19
# 25
# Saved video 330 out of 1255 - Wait, Wait... Throw It!! - Fails of the Week (August 2017) _ FailArmy22
# 25
# Saved video 331 out of 1255 - Wakeboard Wipeout - Fails of the Week (April 2019) _ FailArmy21
# 25
# Saved video 332 out of 1255 - Wall of Fails - Wall Fails (February 2019) _ FailArmy11
# Saved video 333 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy16
# 25
# Saved video 334 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy57
# 25
# Saved video 335 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy6
# 25
# Saved video 336 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy61
# 25
# Saved video 337 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy65
# 25
# Saved video 338 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy71
# 25
# Saved video 339 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy75
# 25
# Saved video 340 out of 1255 - What a Drag - Fails You Missed #18 _ FailArmy76
# 25
# Saved video 341 out of 1255 - Wheelie Gone Wrong - Fails of the Week (October 2018) _ FailArmy29
# 25
# Saved video 342 out of 1255 - When Nothing Goes Right - Throwback Fails (June 2017) _ FailArmy8
# 25
# Saved video 343 out of 1255 - Winter Sports 2018 Fails - See You On The Hill! (February 2018) _ FailArmy45
# 25
# Saved video 344 out of 1255 - Work Sucks! - Failing At Work (June 2018) _ FailArmy16
# 25
# Saved video 345 out of 1255 - You Can't Win 'Em All - Fails of the Week (December 2016) _ FailArmy48
# 25
# Saved video 346 out of 1255 - You're Going Way Too Fast! - Throwback Thursday (September 2017) _ FailArmy14
# 25
# Saved video 347 out of 1255 - You're Going Way Too Fast! - Throwback Thursday (September 2017) _ FailArmy80
# 25
# Saved video 348 out of 1255 - 25 Best Trampoline Fail Nominees - FailArmy Hall of Fame (July 2017)23
# 25
# Saved video 349 out of 1255 - 26 Bad Friend Nominees - FailArmy Hall Of Fame (May 2017) HD12
# 25
# Saved video 350 out of 1255 - 27 Hilarious Cooking Fail Nominees - FailArmy Hall of Fame (July 2017)20
# 25
# Saved video 351 out of 1255 - 28 Best Skateboard Fail Nominees - FailArmy Hall of Fame (August 2017)27
# 25
# Saved video 352 out of 1255 - 29 Best Work Fail Nominees - FailArmy Hall of Fame (August 2017)25
# 25
# Saved video 353 out of 1255 - 29 Best Work Fail Nominees - FailArmy Hall of Fame (August 2017)5
# 25
# Saved video 354 out of 1255 - 31 Back To School Fail Nominees - FailArmy Hall of Fame (September 2017)27
# 25
# Saved video 355 out of 1255 - 31 Back To School Fail Nominees - FailArmy Hall of Fame (September 2017)34
# 25
# Saved video 356 out of 1255 - 31 Senior Citizen Fails - FailArmy Hall of Fame (September 2017)9
# 25
# Saved video 357 out of 1255 - 38 Parkour Fail Nominees - FailArmy Hall Of Fame (May 2017)15
# 25
# Saved video 358 out of 1255 - 38 Parkour Fail Nominees - FailArmy Hall Of Fame (May 2017)18
# 25
# Saved video 359 out of 1255 - 38 Parkour Fail Nominees - FailArmy Hall Of Fame (May 2017)34
# 25
# Saved video 360 out of 1255 - A Christmas Miracle! - Fails You Missed #21 (December 2017) _ FailArmy74
# 25
# Saved video 361 out of 1255 - Alley OOPS - Fails of the Week (October 2017)10
# 25
# Saved video 362 out of 1255 - Alley OOPS - Fails of the Week (October 2017)13
# 25
# Saved video 363 out of 1255 - Alley OOPS - Fails of the Week (October 2017)17
# 25
# Saved video 364 out of 1255 - Alley OOPS - Fails of the Week (October 2017)31
# 25
# Saved video 365 out of 1255 - Alley OOPS - Fails of the Week (October 2017)8
# 25
# Saved video 366 out of 1255 - Always Wear Your Helmet - Fails of the Week (July 2018) _ FailArmy9
# 25
# Saved video 367 out of 1255 - Amazing Snow vs. Surf Fails - FailArmy Presents31
# 25
# Saved video 368 out of 1255 - Amazing Snow vs. Surf Fails - FailArmy Presents69
# 25
# Saved video 369 out of 1255 - American Fails (July 2017) _ FailArmy24
# 25
# Saved video 370 out of 1255 - American Fails (July 2017) _ FailArmy50
# 25
# Saved video 371 out of 1255 - Ants Are Marching - Fails of the Month (October 2017) _ FailArmy12
# 25
# Saved video 372 out of 1255 - Ants Are Marching - Fails of the Month (October 2017) _ FailArmy30
# 25
# Saved video 373 out of 1255 - Ants Are Marching - Fails of the Month (October 2017) _ FailArmy37
# 25
# Saved video 374 out of 1255 - Ants Are Marching - Fails of the Month (October 2017) _ FailArmy53
# 25
# Saved video 375 out of 1255 - Armpit Wax - Fails You Missed (April 2018) _ 201858
# 25
# Saved video 376 out of 1255 - Armpit Wax - Fails You Missed (April 2018) _ 201899
# 25
# Saved video 377 out of 1255 - Baby's Stealing Out Here - Fails of the Week - (April 2017) _ FailArmy31
# 25
# Saved video 378 out of 1255 - Back in the Mud - Down and Dirty Fails (October 2018) _ FailArmy17
# 25
# Saved video 379 out of 1255 - Back in the Mud - Down and Dirty Fails (October 2018) _ FailArmy3
# 25
# Saved video 380 out of 1255 - Back in the Mud - Down and Dirty Fails (October 2018) _ FailArmy35
# 25
# Saved video 381 out of 1255 - Back in USSR (February 2019) _ FailArmy17
# 25
# Saved video 382 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy26
# 25
# Saved video 383 out of 1255 - Backflipping Bros - Fails of the Month! (May 2018) _ Failarmy6
# 25
# Saved video 384 out of 1255 - Basketball Fails - March Madness! (March 2017) _ FailArmy19
# 25
# Saved video 385 out of 1255 - Basketball Fails - March Madness! (March 2017) _ FailArmy36
# 25
# Saved video 386 out of 1255 - Batter Up - America's Past Time Fails (August 2018) _ FailArmy2
# 25
# Saved video 387 out of 1255 - Bend Your Knees!! - Fails of the Week (September 2017) _ FailArmy39
# 25
# Saved video 388 out of 1255 - Bend Your Knees!! - Fails of the Week (September 2017) _ FailArmy43
# 25
# Saved video 389 out of 1255 - Bend Your Knees!! - Fails of the Week (September 2017) _ FailArmy49
# 25
# Saved video 390 out of 1255 - Best Fail of the Week - Bad Kitty! (April 2018) _ FailArmy25
# 25
# Saved video 391 out of 1255 - Best Fail of the Week - Bad Kitty! (April 2018) _ FailArmy42
# 25
# Saved video 392 out of 1255 - Best Fails of the Month - Driving Me Crazy! (January 2018) _ FailArmy3
# 25
# Saved video 393 out of 1255 - Best Fails of the Month - Driving Me Crazy! (January 2018) _ FailArmy42
# 25
# Saved video 394 out of 1255 - Best Fails Of The Month - I Can't Hear! (February 2018) _ FailArmy15
# 25
# Saved video 395 out of 1255 - Best Fails Of The Month - I Can't Hear! (February 2018) _ FailArmy23
# 25
# Saved video 396 out of 1255 - Best Fails Of The Month - I Can't Hear! (February 2018) _ FailArmy30
# 25
# Saved video 397 out of 1255 - Best Fails of the Month April 2016 _ FailArmy0
# Saved video 398 out of 1255 - Best Fails of the Month April 2016 _ FailArmy18
# 25
# Saved video 399 out of 1255 - Best Fails of the Month April 2016 _ FailArmy47
# 25
# Saved video 400 out of 1255 - Best Fails of the Month April 2016 _ FailArmy50
# 25
# Saved video 401 out of 1255 - Best Fails of the Month April 2016 _ FailArmy65
# 25
# Saved video 402 out of 1255 - Best Fails of the Month February 2016 _ 'Babe, You're Actually Crazy!' FailArmy37
# 25
# Saved video 403 out of 1255 - Best Fails of the Month May 2016 _ FailArmy7
# 25
# Saved video 404 out of 1255 - Best Fails of the Week - Go Hard, Or Go Home! (March 2018) _ FailArmy20
# 25
# Saved video 405 out of 1255 - Best Fails of the Week - Is Winter Done Yet (January 2018) _ FailArmy4
# 25
# Saved video 406 out of 1255 - Best Fails of the Week - Is Winter Done Yet (January 2018) _ FailArmy44
# 25
# Saved video 407 out of 1255 - Best Fails of the Week - Is Winter Done Yet (January 2018) _ FailArmy7
# 25
# Saved video 408 out of 1255 - Best Fails of the Week - It's Raining Inside! (February 2018) _ FailArmy29
# 25
# Saved video 409 out of 1255 - Best Fails of the Week - My Life Flashed Before My Eyes! (January 2018) _ FailArmy11
# 25
# Saved video 410 out of 1255 - Best Fails of the Week - My Life Flashed Before My Eyes! (January 2018) _ FailArmy16
# 25
# Saved video 411 out of 1255 - Best Fails of the Week - My Life Flashed Before My Eyes! (January 2018) _ FailArmy23
# 25
# Saved video 412 out of 1255 - Best Fails of the Week - My Life Flashed Before My Eyes! (January 2018) _ FailArmy30
# 25
# Saved video 413 out of 1255 - Best Fails of the Week - My Life Flashed Before My Eyes! (January 2018) _ FailArmy43
# 25
# Saved video 414 out of 1255 - Best Fails of the Week - T-Rex Can Shred! (February 2018 _ FailArmy21
# 25
# Saved video 415 out of 1255 - Best Fails of the Week - T-Rex Can Shred! (February 2018 _ FailArmy35
# 25
# Saved video 416 out of 1255 - Best Fails of the Week - T-Rex Can Shred! (February 2018 _ FailArmy36
# 25
# Saved video 417 out of 1255 - Best Fails of the Week - This Is Poppin' (January 2018) _ FailArmy16
# 25
# Saved video 418 out of 1255 - Best Fails of the Week 1 April 2016 _ 'You Knew That Was Going To Happen!' FailArmy22
# 25
# Saved video 419 out of 1255 - Best Fails of the Week 1 April 2016 _ 'You Knew That Was Going To Happen!' FailArmy45
# 25
# Saved video 420 out of 1255 - Best Fails of the Week 1 April 2016 _ 'You Knew That Was Going To Happen!' FailArmy46
# 25
# Saved video 421 out of 1255 - Best Fails of the Week 1 June 2016 _ FailArmy25
# 25
# Saved video 422 out of 1255 - Best Fails of the Week 1 June 2016 _ FailArmy28
# 25
# Saved video 423 out of 1255 - Best Fails of the Week 1 June 2016 _ FailArmy5
# 25
# Saved video 424 out of 1255 - Best Fails of the Week 1 March 2016 _ 'WTF Was that!' by FailArmy0
# 25
# Saved video 425 out of 1255 - Best Fails of the Week 1 May 2016 _ 'That Squirrel Just Attacked Me! by FailArmy20
# 25
# Saved video 426 out of 1255 - Best Fails of the Week 1 May 2016 _ 'That Squirrel Just Attacked Me! by FailArmy29
# 25
# Saved video 427 out of 1255 - Best Fails of the Week 1 May 2016 _ 'That Squirrel Just Attacked Me! by FailArmy75
# 25
# Saved video 428 out of 1255 - Best Fails of the Week 2 April 2016 _ 'I Knew That Was a Bad Idea' by FailArmy0
# 25
# Saved video 429 out of 1255 - Best Fails of the Week 2 April 2016 _ 'I Knew That Was a Bad Idea' by FailArmy11
# 25
# Saved video 430 out of 1255 - Best Fails of the Week 2 April 2016 _ 'I Knew That Was a Bad Idea' by FailArmy3
# 25
# Saved video 431 out of 1255 - Best Fails of the Week 2 May 2016 _ FailArmy 'That Was An Epic Fail Sam'46
# 25
# Saved video 432 out of 1255 - Best Fails of the Week 2 May 2016 _ FailArmy 'That Was An Epic Fail Sam'74
# Saved video 433 out of 1255 - Best Fails of the Week 2 May 2016 _ FailArmy 'That Was An Epic Fail Sam'79
# 25
# Saved video 434 out of 1255 - Best Fails of the Week 3 April 2016 _ FailArmy17
# 25
# Saved video 435 out of 1255 - Best Fails of the Week 3 April 2016 _ FailArmy7
# 25
# Saved video 436 out of 1255 - Best Fails of the Week 3 March 2016 _ 'You Are An Epic Fail!' by FailArmy20
# 25
# Saved video 437 out of 1255 - Best Fails of the Week 4 March 2016 _ 'Not Today!!' FailArmy7
# 25
# Saved video 438 out of 1255 - Best Fails of the Year - Part 1 (2018) _ FailArmy13
# 25
# Saved video 439 out of 1255 - Best Fails of the Year - Part 1 (2018) _ FailArmy2
# 25
# Saved video 440 out of 1255 - Best Fails of the Year - Part 1 (2018) _ FailArmy38
# 25
# Saved video 441 out of 1255 - Best Fails of the Year - Part 1 (2018) _ FailArmy42
# 25
# Saved video 442 out of 1255 - Best Fails of the Year - Part 2 (2018) _ FailArmy17
# 25
# Saved video 443 out of 1255 - Best Fails of the Year - Part 2 (2018) _ FailArmy36
# 25
# Saved video 444 out of 1255 - Best Fails of the Year - Part 2 (2018) _ FailArmy4
# 25
# Saved video 445 out of 1255 - Best Fails of the Year - Part 2 (2018) _ FailArmy51
# 25
# Saved video 446 out of 1255 - Best Fails of the Year - Part 2 (2018) _ FailArmy52
# 25
# Saved video 447 out of 1255 - Best Fails of the Year 2016 (So Far) _ FailArmy Fail Compilation20
# 25
# Saved video 448 out of 1255 - Best Fails of the Year 2017 (So Far) _ FailArmy105
# 25
# Saved video 449 out of 1255 - Best Fails of the Year 2017 (So Far) _ FailArmy106
# 25
# Saved video 450 out of 1255 - Best Fails of the Year 2017 - Part 2 (December 2017) _ FailArmy87
# 25
# Saved video 451 out of 1255 - Best Fails of the Year 2017 - Part 2 (December 2017) _ FailArmy89
# 25
# Saved video 452 out of 1255 - Best Fails of the Year 2018 (So Far) _ FailArmy0
# 25
# Saved video 453 out of 1255 - Best Fails of Week 1 July 2016 _ FailArmy12
# 25
# Saved video 454 out of 1255 - Best Fails of Week 1 July 2016 _ FailArmy18
# 25
# Saved video 455 out of 1255 - Best Fails of Week 1 July 2016 _ FailArmy5
# 25
# Saved video 456 out of 1255 - Best Fails of Week 2 July 2016 _ FailArmy9
# 25
# Saved video 457 out of 1255 - Best Fails of Week 2 June 2016 _ FailArmy11
# 25
# Saved video 458 out of 1255 - Best Fails of Week 4 June 2016 _ FailArmy22
# 25
# Saved video 459 out of 1255 - Best Fails of Week 4 June 2016 _ FailArmy46
# 25
# Saved video 460 out of 1255 - Best Fails of Week 4 June 2016 _ FailArmy6
# 25
# Saved video 461 out of 1255 - Best Funny Kid Fails Compilation Part 2 _ FailArmy 20160
# 25
# Saved video 462 out of 1255 - Best Pranks - Got ya! (February 2017) _ FailArmy19
# 25
# Saved video 463 out of 1255 - Big Air - Soaring with Style! (September 2017) _ FailArmy22
# 25
# Saved video 464 out of 1255 - Big Air - Soaring with Style! (September 2017) _ FailArmy26
# 25
# Saved video 465 out of 1255 - Big Air - Soaring with Style! (September 2017) _ FailArmy41
# 25
# Saved video 466 out of 1255 - Big Air - Soaring with Style! (September 2017) _ FailArmy60
# 25
# Saved video 467 out of 1255 - Boatloads of Fails - Throwback Thursday (August 2017)32
# 25
# Saved video 468 out of 1255 - Boatloads of Fails - Throwback Thursday (August 2017)41
# 25
# Saved video 469 out of 1255 - Boatloads of Fails - Throwback Thursday (August 2017)60
# 25
# Saved video 470 out of 1255 - Boatloads of Fails - Throwback Thursday (August 2017)79
# 25
# Saved video 471 out of 1255 - Boatloads of Fails - Throwback Thursday (August 2017)97
# 25
# Saved video 472 out of 1255 - Bowling For Fails - Submission Show (April 2018) _ FailArmy12
# 25
# Saved video 473 out of 1255 - Brain Freeze Is Real! - Fails of the Month (June 2017) _ FailArmy11
# 25
# Saved video 474 out of 1255 - Brain Freeze Is Real! - Fails of the Month (June 2017) _ FailArmy27
# 25
# Saved video 475 out of 1255 - Brain Freeze Is Real! - Fails of the Month (June 2017) _ FailArmy9
# 25
# Saved video 476 out of 1255 - Brother Fails _ 'Bros For Life' By FailArmy 201628
# 25
# Saved video 477 out of 1255 - Brother Fails _ 'Bros For Life' By FailArmy 20164
# 25
# Saved video 478 out of 1255 - Carnival of Excess (March 2019) _ FailArmy11
# 25
# Saved video 479 out of 1255 - Cars vs. Bikes - FailArmy Versus (November 2017) _ FailArmy30
# 25
# Saved video 480 out of 1255 - Cars vs. Bikes - FailArmy Versus (November 2017) _ FailArmy7
# 25
# Saved video 481 out of 1255 - Cars vs. Bikes - FailArmy Versus (November 2017) _ FailArmy9
# 25
# Saved video 482 out of 1255 - Cat's Hate Plastic! - Best Fails of the Week _ FailArmy21
# 25
# Saved video 483 out of 1255 - Cat's Hate Plastic! - Best Fails of the Week _ FailArmy28
# 25
# Saved video 484 out of 1255 - Cat's Hate Plastic! - Best Fails of the Week _ FailArmy36
# 25
# Saved video 485 out of 1255 - Cats vs. Birds - FailArmy Versus (October 2017) _ FailArmy10
# 25
# Saved video 486 out of 1255 - Christmas Fails (December 2016) _ FailArmy7
# 25
# Saved video 487 out of 1255 - Close Calls - Best of the Year 2017 _ FailArmy2
# 25
# Saved video 488 out of 1255 - Close Calls - Best of the Year 2017 _ FailArmy40
# 25
# Saved video 489 out of 1255 - Commuting Fails - Crazy Drivers! (January 2018) _ FailArmy0
# 25
# Saved video 490 out of 1255 - Damaged Goods _ Funny Fails and Broken Things by FailArmy14
# 25
# Saved video 491 out of 1255 - Damaged Goods _ Funny Fails and Broken Things by FailArmy19
# 25
# Saved video 492 out of 1255 - Damaged Goods _ Funny Fails and Broken Things by FailArmy42
# 25
# Saved video 493 out of 1255 - Desert Fails - The Sands of Failure (November 2018) _ FailArmy0
# 25
# Saved video 494 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy13
# 25
# Saved video 495 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy21
# 25
# Saved video 496 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy28
# 25
# Saved video 497 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy31
# 25
# Saved video 498 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy38
# 25
# Saved video 499 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy41
# 25
# Saved video 500 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy45
# 25
# Saved video 501 out of 1255 - Didn't Make The Team - Better luck next time!  (September 2017) _ FailArmy5
# 25
# Saved video 502 out of 1255 - Doggone It! - Fails You Missed #23 (December 2017) _ FailArmy0
# 25
# Saved video 503 out of 1255 - Doggone It! - Fails You Missed #23 (December 2017) _ FailArmy34
# 25
# Saved video 504 out of 1255 - Doggone It! - Fails You Missed #23 (December 2017) _ FailArmy39
# 25
# Saved video 505 out of 1255 - Doggone It! - Fails You Missed #23 (December 2017) _ FailArmy43
# 25
# Saved video 506 out of 1255 - Doggone It! - Fails You Missed #23 (December 2017) _ FailArmy49
# 25
# Saved video 507 out of 1255 - Dogs Are Man's Best Fails!! (May 2018) _ FailArmy21
# 25
# Saved video 508 out of 1255 - Don't Drive In Russia - Fails You Missed #19 (December 2017) _ FailArmy0
# 25
# Saved video 509 out of 1255 - Don't Drive In Russia - Fails You Missed #19 (December 2017) _ FailArmy10
# 25
# Saved video 510 out of 1255 - Don't Rock the Boat! - Throwback Fails (February 2018) _ FailArmy32
# 25
# Saved video 511 out of 1255 - Don't Rock the Boat! - Throwback Fails (February 2018) _ FailArmy41
# 25
# Saved video 512 out of 1255 - Don't Rock the Boat! - Throwback Fails (February 2018) _ FailArmy42
# 25
# ...
# 25
# Saved video 1086 out of 1255 - The Master Swordsmen - Fails You Missed #17 _ FailArmy69
# 25
# Saved video 1087 out of 1255 - The Master Swordsmen - Fails You Missed #17 _ FailArmy8
# 25
# Saved video 1088 out of 1255 - The Summer of Fails - Fails of the Week (July 2018) _ FailArmy20
# 25
# Saved video 1089 out of 1255 - The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy39
# 25
# Saved video 1090 out of 1255 - Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy11
# 25
# Saved video 1091 out of 1255 - Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy12
# 25
# Saved video 1092 out of 1255 - Throwback Fails - Saved It! (January 2018) _ FailArmy28
# 25
# Saved video 1093 out of 1255 - Throwback Fails - That's one greedy cat!78
# 25
# Saved video 1094 out of 1255 - Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'55
# 25
# Saved video 1095 out of 1255 - Whip It, Whip It Real Good - Fails of the Month (November 2017) _ FailArmy1
# 25
# Saved video 1096 out of 1255 - 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)21
# 25
# Saved video 1097 out of 1255 - Anger Management - Fails of the Week (January 2019) _ FailArmy12
# 25
# Saved video 1098 out of 1255 - Anger Management - Fails of the Week (January 2019) _ FailArmy2
# 25
# Saved video 1099 out of 1255 - Are You Serious! - Throwback Thursday (September 2017) _ FailArmy11
# 25
# Saved video 1100 out of 1255 - Are You Serious! - Throwback Thursday (September 2017) _ FailArmy78
# 25
# Saved video 1101 out of 1255 - Are You Serious! - Throwback Thursday (September 2017) _ FailArmy80
# 25
# Saved video 1102 out of 1255 - Bats & Balls Fail Compilation _ By FailArmy 201648
# 25
# Saved video 1103 out of 1255 - Bee Keeper Business - Fails of the Week (November 2018) _ FailArmy0
# 25
# Saved video 1104 out of 1255 - Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy17
# 25
# Saved video 1105 out of 1255 - Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy31
# 25
# Saved video 1106 out of 1255 - Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy8
# 25
# Saved video 1107 out of 1255 - Best Fails of the Week 2 March 2016 _ 'I Think We Got What We're Looking For' by FailArmy11
# 25
# Saved video 1108 out of 1255 - Best Fails of the Week 3 February 2016 _ 'I'm OK, Wheres my Jetski!'FailArmy10
# 25
# Saved video 1109 out of 1255 - Best Fails of the Week 3 May 2016 _ FailArmy32
# 25
# Saved video 1110 out of 1255 - Best Fails of the Week 3 May 2016 _ FailArmy70
# 25
# Saved video 1111 out of 1255 - Best Fails of the Week 3 May 2016 _ FailArmy83
# 25
# Saved video 1112 out of 1255 - Break Yourself - Fails of the Week (September 2017) _ FailArmy21
# 25
# Saved video 1113 out of 1255 - Break Yourself - Fails of the Week (September 2017) _ FailArmy26
# Saved video 1114 out of 1255 - Classic bails and Throwback Fails (June 2017) _ FailArmy32
# 25
# Saved video 1115 out of 1255 - Classic bails and Throwback Fails (June 2017) _ FailArmy67
# 25
# Saved video 1116 out of 1255 - Confidence is Key - Fails of the Week (December 2016) _ FailArmy0
# 25
# Saved video 1117 out of 1255 - Confidence is Key - Fails of the Week (December 2016) _ FailArmy14
# 25
# Saved video 1118 out of 1255 - Confidence is Key - Fails of the Week (December 2016) _ FailArmy23
# 25
# Saved video 1119 out of 1255 - Confidence is Key - Fails of the Week (December 2016) _ FailArmy36
# 25
# Saved video 1120 out of 1255 - Confidence is Key - Fails of the Week (December 2016) _ FailArmy4
# 25
# Saved video 1121 out of 1255 - Confidence is Key - Fails of the Week (December 2016) _ FailArmy8
# 25
# Saved video 1122 out of 1255 - Crack That Whip - Throwback Fails (July 2017)27
# 25
# Saved video 1123 out of 1255 - Crack That Whip - Throwback Fails (July 2017)37
# 25
# Saved video 1124 out of 1255 - Crack That Whip - Throwback Fails (July 2017)65
# 25
# Saved video 1125 out of 1255 - Don't Be Such a Baby - Kid Fails (September 2018) _ FailArmy24
# 25
# Saved video 1126 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)132
# 25
# Saved video 1127 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)15
# 25
# Saved video 1128 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)17
# 25
# Saved video 1129 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)19
# 25
# Saved video 1130 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)63
# 25
# Saved video 1131 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)86
# 25
# Saved video 1132 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)89
# 25
# Saved video 1133 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)92
# 25
# Saved video 1134 out of 1255 - Don't Get Zapped - Throwback Thursday (August 2017)99
# 25
# Saved video 1135 out of 1255 - Don't Rock the Boat - Throwback Fails (July 2017)54
# 25
# Saved video 1136 out of 1255 - Don't Rock the Boat - Throwback Fails (July 2017)58
# 25
# Saved video 1137 out of 1255 - Expensive Fails - That's Going To Cost You! (July 2017)14
# 25
# Saved video 1138 out of 1255 - Expensive Fails - That's Going To Cost You! (July 2017)5
# 25
# Saved video 1139 out of 1255 - FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)110
# Saved video 1140 out of 1255 - FailArmy After Dark - Party On!  (Ep. 3)10
# Saved video 1141 out of 1255 - FailArmy After Dark - Party On!  (Ep. 3)175
# 25
# Saved video 1142 out of 1255 - FailArmy After Dark - Party On!  (Ep. 3)179
# 25
# Saved video 1143 out of 1255 - FailArmy After Dark - Party On!  (Ep. 3)24
# 25
# Saved video 1144 out of 1255 - FailArmy After Dark - Party On!  (Ep. 3)28
# 25
# Saved video 1145 out of 1255 - FailArmy After Dark - Party On!  (Ep. 3)41
# 25
# Saved video 1146 out of 1255 - FailArmy After Dark - Say It, Don't Spray It (Ep. 7)102
# 25
# Saved video 1147 out of 1255 - FailArmy After Dark - Say It, Don't Spray It (Ep. 7)54
# 25
# Saved video 1148 out of 1255 - FailArmy After Dark - Say It, Don't Spray It (Ep. 7)6
# 25
# Saved video 1149 out of 1255 - FailArmy After Dark - Say It, Don't Spray It (Ep. 7)69
# 25
# Saved video 1150 out of 1255 - FailArmy After Dark - Say It, Don't Spray It (Ep. 7)88
# 25
# Saved video 1151 out of 1255 - FailArmy After Dark - That's Going To Cost You  (Ep. 10)103
# 25
# Saved video 1152 out of 1255 - FailArmy After Dark - That's Got to Sting (Ep. 6)20
# 25
# Saved video 1153 out of 1255 - FailArmy After Dark - That's Got to Sting (Ep. 6)95
# 25
# Saved video 1154 out of 1255 - FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy126
# 25
# Saved video 1155 out of 1255 - FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy142
# 25
# Saved video 1156 out of 1255 - FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy146
# 25
# Saved video 1157 out of 1255 - FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy178
# 25
# Saved video 1158 out of 1255 - FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy241
# 25
# Saved video 1159 out of 1255 - FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy89
# 25
# Saved video 1160 out of 1255 - FailArmy's Got Talent (October 2017) _ FailArmy13
# 25
# Saved video 1161 out of 1255 - FailArmy's Got Talent (October 2017) _ FailArmy16
# 25
# Saved video 1162 out of 1255 - FailArmy's Got Talent (October 2017) _ FailArmy40
# 25
# Saved video 1163 out of 1255 - FailFactory - Derpy Dogs (March 2019) _ FailArmy72
# 25
# Saved video 1164 out of 1255 - FailFactory - Derpy Dogs (March 2019) _ FailArmy89
# 25
# Saved video 1165 out of 1255 - FailFactory - No Pain, No Gain (Workout Fails)14
# 25
# Saved video 1166 out of 1255 - FailFactory - No Pain, No Gain (Workout Fails)23
# 25
# Saved video 1167 out of 1255 - FailFactory - No Pain, No Gain (Workout Fails)66
# 25
# Saved video 1168 out of 1255 - FailFactory - No Pain, No Gain (Workout Fails)78
# 25
# Saved video 1169 out of 1255 - FailFactory - No Pain, No Gain (Workout Fails)88
# 25
# Saved video 1170 out of 1255 - FailFactory - No Pain, No Gain (Workout Fails)95
# 25
# Saved video 1171 out of 1255 - Fails of the Month (December 2016) _ FailArmy12
# 25
# Saved video 1172 out of 1255 - Fails of the Month (December 2016) _ FailArmy48
# 25
# Saved video 1173 out of 1255 - Fails of the Month (December 2016) _ FailArmy6
# 25
# Saved video 1174 out of 1255 - Fails of the Month - Failing into Summer like... (May 2017)26
# 25
# Saved video 1175 out of 1255 - Fails of the Month - Failing into Summer like... (May 2017)40
# 25
# Saved video 1176 out of 1255 - Fails of the Month - Failing into Summer like... (May 2017)49
# 25
# Saved video 1177 out of 1255 - Fails of the Week (March 2017) _ FailArmy33
# 25
# Saved video 1178 out of 1255 - Fails of the Week - Insult to Injury (January 2017) _ FailArmy6
# 25
# Saved video 1179 out of 1255 - Fails of the Week - Let's Do This Thing! (April 2017)35
# 25
# Saved video 1180 out of 1255 - Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy42
# 25
# Saved video 1181 out of 1255 - Fails of the Week 4 September 2016 _ FailArmy27
# 25
# Saved video 1182 out of 1255 - Fails of the Week 4 September 2016 _ FailArmy29
# 25
# Saved video 1183 out of 1255 - Fails of the Week 4 September 2016 _ FailArmy48
# 25
# Saved video 1184 out of 1255 - Father's Day Fails _ 'Dad Fails' By FailArmy 201614
# 25
# Saved video 1185 out of 1255 - Father's Day Fails _ 'Dad Fails' By FailArmy 201618
# 25
# Saved video 1186 out of 1255 - Funny Animal Fails - Just In Time For Election 2016 _ Fail Army63
# 25
# Saved video 1187 out of 1255 - Funny Kid Fails (February 2016) _ FailArmy4
# 25
# Saved video 1188 out of 1255 - Funny School Fails Compilation _ 'School's Out' By FailArmy 201619
# 25
# Saved video 1189 out of 1255 - Funny Tourist Fails (June 2017) _ FailArmy15
# 25
# Saved video 1190 out of 1255 - Funny Tourist Fails (June 2017) _ FailArmy37
# 25
# Saved video 1191 out of 1255 - Get Out Of The Way!! - FailArmy After Dark (Ep. 12)132
# 25
# Saved video 1192 out of 1255 - Get Out Of The Way!! - FailArmy After Dark (Ep. 12)136
# 25
# Saved video 1193 out of 1255 - Get Out Of The Way!! - FailArmy After Dark (Ep. 12)28
# 25
# Saved video 1194 out of 1255 - Grandmas vs Grandpas - FailArmy Versus (December 2017) _ FailArmy21
# 25
# Saved video 1195 out of 1255 - Hilarious Holiday Fails (December 2017) _ FailArmy27
# 25
# Saved video 1196 out of 1255 - I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy0
# 25
# Saved video 1197 out of 1255 - I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy69
# 25
# Saved video 1198 out of 1255 - I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy82
# 25
# Saved video 1199 out of 1255 - It's All Down Hill From Here - Throwback Fails (August 2017)10
# 25
# Saved video 1200 out of 1255 - It's All Down Hill From Here - Throwback Fails (August 2017)23
# 25
# Saved video 1201 out of 1255 - It's All Down Hill From Here - Throwback Fails (August 2017)4
# 25
# Saved video 1202 out of 1255 - It's All Down Hill From Here - Throwback Fails (August 2017)80
# 25
# Saved video 1203 out of 1255 - Let's Get It!! - FailArmy After Dark (ep. 2)215
# 25
# Saved video 1204 out of 1255 - Let's Get Tropical - Beach Fails25
# 25
# Saved video 1205 out of 1255 - Lets Get Stoned - Rock Fails11
# 25
# Saved video 1206 out of 1255 - Mirror Fight Back - Fails of the Week (November 2017) _ FailArmy17
# 25
# Saved video 1207 out of 1255 - Mirror Fight Back - Fails of the Week (November 2017) _ FailArmy4
# 25
# Saved video 1208 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy11
# 25
# Saved video 1209 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy12
# 25
# Saved video 1210 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy60
# 25
# Saved video 1211 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy71
# 25
# Saved video 1212 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy85
# 25
# Saved video 1213 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy90
# 25
# Saved video 1214 out of 1255 - Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy99
# 25
# Saved video 1215 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy17
# 25
# Saved video 1216 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy23
# 25
# Saved video 1217 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy26
# 25
# Saved video 1218 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy3
# 25
# Saved video 1219 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy33
# 25
# Saved video 1220 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy47
# 25
# Saved video 1221 out of 1255 - Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy6
# 25
# Saved video 1222 out of 1255 - On The Job Fails - I Need A New Job (October 2017) _ FailArmy19
# 25
# Saved video 1223 out of 1255 - Rapper Slips off the Stage!! - Fails of the Week (July 2017)30
# 25
# Saved video 1224 out of 1255 - Sister Fails _ Funny Sisters Fail Compilation By FailArmy 201617
# 25
# Saved video 1225 out of 1255 - Sister Fails _ Funny Sisters Fail Compilation By FailArmy 201621
# 25
# Saved video 1226 out of 1255 - Sister Fails _ Funny Sisters Fail Compilation By FailArmy 201622
# 25
# Saved video 1227 out of 1255 - That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy15
# 25
# Saved video 1228 out of 1255 - The Master Swordsmen - Fails You Missed #17 _ FailArmy17
# 25
# Saved video 1229 out of 1255 - The Master Swordsmen - Fails You Missed #17 _ FailArmy44
# 25
# Saved video 1230 out of 1255 - The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy0
# 25
# Saved video 1231 out of 1255 - Throwback Fails - Backflip Belly Flops Optional! (December 2017) _ FailArmy18
# 25
# Saved video 1232 out of 1255 - Throwback Fails - Backflip Belly Flops Optional! (December 2017) _ FailArmy84
# 25
# Saved video 1233 out of 1255 - Throwback Fails - Carriage Carnage (April 2018) _ FailArmy14
# 25
# Saved video 1234 out of 1255 - Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy14
# 25
# Saved video 1235 out of 1255 - Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy28
# 25
# Saved video 1236 out of 1255 - Throwback Fails - Jump Around! (March 2018) _ FailArmy11
# 25
# Saved video 1237 out of 1255 - Throwback Fails - Jump Around! (March 2018) _ FailArmy39
# 25
# Saved video 1238 out of 1255 - Throwback Fails - Jump Around! (March 2018) _ FailArmy42
# 25
# Saved video 1239 out of 1255 - Throwback Fails - Saved It! (January 2018) _ FailArmy37
# 25
# Saved video 1240 out of 1255 - Throwback Fails - Saved It! (January 2018) _ FailArmy43
# 25
# Saved video 1241 out of 1255 - Throwback Fails - That's one greedy cat!63
# 25
# Saved video 1242 out of 1255 - Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy25
# 25
# Saved video 1243 out of 1255 - Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy42
# 25
# Saved video 1244 out of 1255 - Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy44
# 25
# Saved video 1245 out of 1255 - Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy50
# 25
# Saved video 1246 out of 1255 - Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy52
# 25
# Saved video 1247 out of 1255 - Treadmill Terror - Fails of the Week (November 2018) _ FailArmy10
# 25
# Saved video 1248 out of 1255 - Treadmill Terror - Fails of the Week (November 2018) _ FailArmy8
# 25
# Saved video 1249 out of 1255 - Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'0
# 25
# Saved video 1250 out of 1255 - Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'23
# 25
# Saved video 1251 out of 1255 - Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'25
# 25
# Saved video 1252 out of 1255 - Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'5
# 25
# Saved video 1253 out of 1255 - Ultimate Winter Fails Compilation _ Boards, Skis, and Snow from FailArmy2
# 25
# Saved video 1254 out of 1255 - You've Got Bad Friends - Friendship Fails (September 2018) _ FailArmy17
# 25
# Saved video 1255 out of 1255 - You've Got Bad Friends - Friendship Fails (September 2018) _ FailArmy26
