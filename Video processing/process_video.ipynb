# %%
import os
import sys
annotations_dir = os.path.normpath(os.getcwd() + os.sep + "annotations")
train_dir = os.path.normpath(os.getcwd() + os.sep + "video" + os.sep + "train")
val_dir = os.path.normpath(os.getcwd() + os.sep + "video" + os.sep + "val")
sys.path.append(annotations_dir)
sys.path.append(train_dir)
sys.path.append(val_dir)

import json
import numpy as np
import shutil

# %%
transition_times = {}
def read_transition_times():
    '''
    Read the transition_times.json in annotations folder, for future processing of videos
    '''
    global transition_times

    with open('./annotations/transition_times.json', 'r', encoding='utf-8') as file:
        transition_times = json.load(file)

read_transition_times()

# %%
def deleteTrainUnqualified():
    '''
    Delete unqualified videos according to train_filtered.txt
    Base on transition_times.json, can find videos to delete
    '''
    qualified = []
    with open('./annotations/train_filtered.txt', 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        qualified.append(line.strip() + ".mp4") # record all qualified filenames
    print(len(qualified))
    train_dir = './video/train'
    cnt = 0
    for filename in os.listdir(train_dir):
        if filename not in qualified:
            cnt += 1
            file_path = os.path.join(train_dir, filename)
            os.remove(file_path)
    print("Unqualified video count: ", cnt)
    return qualified

def deleteValUnqualified():
    '''
    Delete unqualified videos according to val_filtered.txt
    Base on transition_times.json, can find videos to delete
    '''
    qualified = []
    with open('./annotations/val_filtered.txt', 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        qualified.append(line.strip() + ".mp4") # record all qualified filenames
    print(len(qualified))
    val_dir = './video/val'
    cnt = 0
    for filename in os.listdir(val_dir):
        if filename not in qualified:
            cnt += 1
            file_path = os.path.join(val_dir, filename)
            os.remove(file_path)
    print("Unqualified video count: ", cnt)
    return qualified

# %%
def count_files_with_n_notfound_3():
    '''
    Count and record videos that are labeled as "Intentional/No oops", and are longer than 5 seconds
    store 2 list of filename strings
    '''
    train_intentional, val_intentional = [], []
    with open('./annotations/train_filtered.txt', 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        filename = line.strip()
        if filename in transition_times and transition_times[filename]["n_notfound"] == 3 \
        and transition_times[filename]["len"] >= 5 and transition_times[filename]["len"] <= 10:
            train_intentional.append(filename)

    with open('./annotations/val_filtered.txt', 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        filename = line.strip()
        if filename in transition_times and transition_times[filename]["n_notfound"] == 3 \
        and transition_times[filename]["len"] >= 5 and transition_times[filename]["len"] <= 10:
            val_intentional.append(filename)

    return train_intentional, val_intentional

# %%
train_intentional, val_intentional = count_files_with_n_notfound_3()
print(len(train_intentional), len(val_intentional))
# Out:
# 347 283

# %%
def count_files_with_n_notfound_0():
    '''
    Count and record videos that are unanimously labeled as "Unintentional/Transitional/Oops", longer than 5 seconds
    store 2 list of filename strings
    '''
    train_oops, val_oops = [], []
    with open('./annotations/train_filtered.txt', 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        filename = line.strip()
        if filename in transition_times and transition_times[filename]["n_notfound"] == 0 \
        and transition_times[filename]["len"] >= 5 and transition_times[filename]["len"] <= 10:
            accident = np.mean(transition_times[filename]["t"])
            accident_min = np.min(transition_times[filename]["t"])
            accident_max = np.max(transition_times[filename]["t"])

            if accident <= 4 and accident >= 1 and accident_max - accident_min < 0.8:
                # Prune away transition time that is too early (< 1), 
                # also prune away transition time after 5 for future video trimming
                train_oops.append(filename)

    with open('./annotations/val_filtered.txt', 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        filename = line.strip()
        if filename in transition_times and transition_times[filename]["n_notfound"] == 0 \
        and transition_times[filename]["len"] >= 5 and transition_times[filename]["len"] <= 10:
            accident = np.mean(transition_times[filename]["t"])
            accident_min = np.min(transition_times[filename]["t"])
            accident_max = np.max(transition_times[filename]["t"])

            if accident <= 4 and accident >= 1 and accident_max - accident_min < 0.8:
                val_oops.append(filename)

    return train_oops, val_oops

# %%
train_oops, val_oops = count_files_with_n_notfound_0()
print(len(train_oops), len(val_oops))
# Out:
# 668 450

# %%
def create_new_folder():
    '''
    Create the new folder structure for selected videos:
    video_small -> (train, val)
    train -> (oops, no_oops)
    val -> (oops, no_oops)
    '''

    # Define the main folder path
    main_folder = "./video_small"
    # Create the main folder if it doesn't exist
    if not os.path.exists(main_folder):
        os.makedirs(main_folder)

    # Define the train and val folders
    train_folder = os.path.join(main_folder, "train")
    val_folder = os.path.join(main_folder, "val")

    # Create the train and val folders if they don't exist
    for folder in [train_folder, val_folder]:
        if not os.path.exists(folder):
            os.makedirs(folder)

    # Define subfolders for train and val
    train_no_oops_folder = os.path.join(train_folder, "no_oops")
    train_oops_folder = os.path.join(train_folder, "oops")
    val_no_oops_folder = os.path.join(val_folder, "no_oops")
    val_oops_folder = os.path.join(val_folder, "oops")

    # Create subfolders for train and val
    for folder in [train_no_oops_folder, train_oops_folder, val_no_oops_folder, val_oops_folder]:
        if not os.path.exists(folder):
            os.makedirs(folder)


def copy_files(source_dir, file_list, dest_dir):
    '''
    Copy the selected videos to new destination with the new folder structure
    '''
    for file_name in file_list:
        source_file = os.path.join(source_dir, file_name + ".mp4")
        destination_file = os.path.join(dest_dir, file_name + ".mp4")
        if os.path.exists(destination_file):
            print(f"File '{file_name}.mp4' already exists in '{dest_dir}'")
        else:
            shutil.copyfile(source_file, destination_file, follow_symlinks=True)
    print(f"Copied files from {source_dir} to {dest_dir}")

# %%
create_new_folder()

# %%
train_intentional = [name.encode('utf-8').decode('utf-8') for name in train_intentional]
train_oops = [name.encode('utf-8').decode('utf-8') for name in train_oops]
val_intentional = [name.encode('utf-8').decode('utf-8') for name in val_intentional]
val_oops = [name.encode('utf-8').decode('utf-8') for name in val_oops]

# %%
copy_files("./video/train", train_intentional, "./video_small/train/no_oops")
# Out:
# Copied files from ./video/train to ./video_small/train/no_oops

# %%
copy_files("./video/train", train_oops, "./video_small/train/oops")
# Out:
# Copied files from ./video/train to ./video_small/train/oops

# %%
copy_files("./video/val", val_intentional, "./video_small/val/no_oops")
# Out:
# Copied files from ./video/val to ./video_small/val/no_oops

# %%
copy_files("./video/val", val_oops, "./video_small/val/oops")
# Out:
# Copied files from ./video/val to ./video_small/val/oops

# %%
small_transition_times = {}

def update_small_transition_times(folder_path, category, label):
    '''
    Create a smaller json base on the selected videos
    '''
    global small_transition_times
    for filename in os.listdir(folder_path):
        if filename.endswith(".mp4"):
            video_name = os.path.splitext(filename)[0]
            if video_name in transition_times:
                small_transition_times[video_name] = transition_times[video_name]
                small_transition_times[video_name]["category"] = category
                small_transition_times[video_name]["label"] = label

# %%
train_no_oops_folder = "./video_small/train/no_oops"
train_oops_folder = "./video_small/train/oops"
val_no_oops_folder = "./video_small/val/no_oops"
val_oops_folder = "./video_small/val/oops"

# %%
# Trim val folder to contain less videos
import os
import random
import shutil

# Define the paths to the video folders
val_no_oops_folder = "./video_small/val/no_oops"
val_oops_folder = "./video_small/val/oops"

# Function to randomly select and delete videos from a folder
def select_and_delete_videos(folder_path, num_to_keep):
    # Get the list of all video files in the folder
    all_videos = os.listdir(folder_path)
    
    # Calculate the number of videos to delete
    num_to_delete = len(all_videos) - num_to_keep
    
    # Randomly select videos to delete
    videos_to_delete = random.sample(all_videos, num_to_delete)
    
    # Delete the selected videos
    for video in videos_to_delete:
        video_path = os.path.join(folder_path, video)
        os.remove(video_path)
        print(f"Deleted {video} from {folder_path}")

# Randomly select and delete videos from val/no_oops folder
select_and_delete_videos(val_no_oops_folder, num_to_keep=80)

# Randomly select and delete videos from val/oops folder
select_and_delete_videos(val_oops_folder, num_to_keep=160)
# Out:
# Deleted We're Back! Fails of the Week (May 2019) _ FailArmy29.mp4 from ./video_small/val/no_oops
# Deleted Field Goal Fail - Fails of the Week (January 2019)11.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy16.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week 3 May 2016 _ FailArmy64.mp4 from ./video_small/val/no_oops
# Deleted We're Back! Fails of the Week (May 2019) _ FailArmy32.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy141.mp4 from ./video_small/val/no_oops
# Deleted The Master Swordsmen - Fails You Missed #17 _ FailArmy76.mp4 from ./video_small/val/no_oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy39.mp4 from ./video_small/val/no_oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201636.mp4 from ./video_small/val/no_oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)40.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)51.mp4 from ./video_small/val/no_oops
# Deleted Anger Management - Fails of the Week (January 2019) _ FailArmy38.mp4 from ./video_small/val/no_oops
# Deleted Field Goal Fail - Fails of the Week (January 2019)30.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy84.mp4 from ./video_small/val/no_oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy91.mp4 from ./video_small/val/no_oops
# Deleted Hopeless Romantic - Fails of the Week (October 2018) _ FailArmy12.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy93.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Month - Failing into Summer like... (May 2017)6.mp4 from ./video_small/val/no_oops
# Deleted The Master Swordsmen - Fails You Missed #17 _ FailArmy61.mp4 from ./video_small/val/no_oops
# Deleted Wheelie Gone Wrong - Fails of the Week (May 2018) _ FailArmy10.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)111.mp4 from ./video_small/val/no_oops
# Deleted Fails at Home - Home Is Where The Fail Is (May 2018) _ FailArmy2.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)35.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy96.mp4 from ./video_small/val/no_oops
# Deleted Caught Slippin' - Fails of the Week (February 2019) _ FailArmy5.mp4 from ./video_small/val/no_oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy36.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - No Pain, No Gain (Workout Fails)138.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy63.mp4 from ./video_small/val/no_oops
# Deleted Let's Get Tropical - Beach Fails15.mp4 from ./video_small/val/no_oops
# Deleted Recording for Duty - I’m So Confused (March 2019) _ FailArmy50.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy42.mp4 from ./video_small/val/no_oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)80.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy7.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - No Pain, No Gain (Workout Fails)43.mp4 from ./video_small/val/no_oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201653.mp4 from ./video_small/val/no_oops
# Deleted Anger Management - Fails of the Week (January 2019) _ FailArmy34.mp4 from ./video_small/val/no_oops
# Deleted Hilarious Science Fails (July 2017) _ FailArmy18.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy10.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)45.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)122.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Insult to Injury (January 2017) _ FailArmy37.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)130.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy45.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)84.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy18.mp4 from ./video_small/val/no_oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy103.mp4 from ./video_small/val/no_oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy47.mp4 from ./video_small/val/no_oops
# Deleted Hopeless Romantic - Fails of the Week (October 2018) _ FailArmy15.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy63.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy52.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy44.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Month - Stuck The Landing!! _ FailArmy1.mp4 from ./video_small/val/no_oops
# Deleted The Master Swordsmen - Fails You Missed #17 _ FailArmy81.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)89.mp4 from ./video_small/val/no_oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy26.mp4 from ./video_small/val/no_oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201630.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week 2 March 2016 _ 'I Think We Got What We're Looking For' by FailArmy18.mp4 from ./video_small/val/no_oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)65.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)5.mp4 from ./video_small/val/no_oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy97.mp4 from ./video_small/val/no_oops
# Deleted Guess it's Time to Leave - Throwback Thursday (October 2017) _ FailArmy60.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)23.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)108.mp4 from ./video_small/val/no_oops
# Deleted The Master Swordsmen - Fails You Missed #17 _ FailArmy67.mp4 from ./video_small/val/no_oops
# Deleted Workout Fails - New Year, Same Me (January 2017) _ FailArmy8.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Let's Do This Thing! (April 2017)12.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)46.mp4 from ./video_small/val/no_oops
# Deleted Don't Rock the Boat - Throwback Fails (July 2017)55.mp4 from ./video_small/val/no_oops
# Deleted Drop On In! - Fails of the Week (June 2018) _ FailArmy5.mp4 from ./video_small/val/no_oops
# Deleted The Master Swordsmen - Fails You Missed #17 _ FailArmy22.mp4 from ./video_small/val/no_oops
# Deleted Recording for Duty - I’m So Confused (March 2019) _ FailArmy9.mp4 from ./video_small/val/no_oops
# Deleted Let's Get Tropical - Beach Fails43.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week 3 February 2016 _ 'I'm OK, Wheres my Jetski!'FailArmy40.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)125.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week 2 March 2016 _ 'I Think We Got What We're Looking For' by FailArmy46.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy65.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy14.mp4 from ./video_small/val/no_oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)99.mp4 from ./video_small/val/no_oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)77.mp4 from ./video_small/val/no_oops
# Deleted Ouchie - Dang That Hurt! (May 2018) _ FailArmy38.mp4 from ./video_small/val/no_oops
# Deleted FailArmy's Got Talent (October 2017) _ FailArmy43.mp4 from ./video_small/val/no_oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy91.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy91.mp4 from ./video_small/val/no_oops
# Deleted Bait and Switch Fails - Fooled you! (January 2018) _ FailArmy15.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)146.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Say It, Don't Spray It (Ep. 7)40.mp4 from ./video_small/val/no_oops
# Deleted Anger Management - Fails of the Week (January 2019) _ FailArmy39.mp4 from ./video_small/val/no_oops
# Deleted Expensive Fails - That's Going To Cost You! (July 2017)47.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)94.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)52.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy66.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Insult to Injury (January 2017) _ FailArmy51.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy113.mp4 from ./video_small/val/no_oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)105.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy71.mp4 from ./video_small/val/no_oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy45.mp4 from ./video_small/val/no_oops
# Deleted FailArmy's Got Talent (October 2017) _ FailArmy38.mp4 from ./video_small/val/no_oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)102.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)117.mp4 from ./video_small/val/no_oops
# Deleted Fails at Home - Home Is Where The Fail Is (May 2018) _ FailArmy14.mp4 from ./video_small/val/no_oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy105.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)44.mp4 from ./video_small/val/no_oops
# Deleted Wheelie Gone Wrong - Fails of the Week (May 2018) _ FailArmy24.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)143.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy107.mp4 from ./video_small/val/no_oops
# Deleted Classic Redneck Waterslide - Throwback Fails (July 2017)102.mp4 from ./video_small/val/no_oops
# Deleted Funny Animal Fails - Just In Time For Election 2016 _ Fail Army64.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy87.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)121.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)94.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)107.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy36.mp4 from ./video_small/val/no_oops
# Deleted Mirror Fight Back - Fails of the Week (November 2017) _ FailArmy34.mp4 from ./video_small/val/no_oops
# Deleted Confidence is Key - Fails of the Week (December 2016) _ FailArmy51.mp4 from ./video_small/val/no_oops
# Deleted Expensive Fails - That's Going To Cost You! (July 2017)50.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy102.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy46.mp4 from ./video_small/val/no_oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy40.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)147.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week 4 September 2016 _ FailArmy25.mp4 from ./video_small/val/no_oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy80.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy4.mp4 from ./video_small/val/no_oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201632.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy8.mp4 from ./video_small/val/no_oops
# Deleted Lets Get Stoned - Rock Fails15.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week 2 March 2016 _ 'I Think We Got What We're Looking For' by FailArmy50.mp4 from ./video_small/val/no_oops
# Deleted Don't Be Such a Baby - Kid Fails (September 2018) _ FailArmy7.mp4 from ./video_small/val/no_oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201647.mp4 from ./video_small/val/no_oops
# Deleted Fails You Missed - Not the Bees (April 2018) _ Failarmy12.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - No Pain, No Gain (Workout Fails)18.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)120.mp4 from ./video_small/val/no_oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy13.mp4 from ./video_small/val/no_oops
# Deleted Caught Slippin' - Fails of the Week (February 2019) _ FailArmy27.mp4 from ./video_small/val/no_oops
# Deleted Ouchie - Dang That Hurt! (May 2018) _ FailArmy31.mp4 from ./video_small/val/no_oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy32.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy128.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy9.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy51.mp4 from ./video_small/val/no_oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy74.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy39.mp4 from ./video_small/val/no_oops
# Deleted Are You Serious! - Throwback Thursday (September 2017) _ FailArmy27.mp4 from ./video_small/val/no_oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy28.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Insult to Injury (January 2017) _ FailArmy14.mp4 from ./video_small/val/no_oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)37.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - That's one greedy cat!21.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)40.mp4 from ./video_small/val/no_oops
# Deleted Ultimate Winter Fails Compilation _ Boards, Skis, and Snow from FailArmy47.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Month (December 2016) _ FailArmy1.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)128.mp4 from ./video_small/val/no_oops
# Deleted Hilarious Holiday Fails (December 2017) _ FailArmy1.mp4 from ./video_small/val/no_oops
# Deleted Wheelie Gone Wrong - Fails of the Week (May 2018) _ FailArmy23.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)108.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)122.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy88.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy1.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)56.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy65.mp4 from ./video_small/val/no_oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy10.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)116.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy63.mp4 from ./video_small/val/no_oops
# Deleted Drop On In! - Fails of the Week (June 2018) _ FailArmy11.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy76.mp4 from ./video_small/val/no_oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)110.mp4 from ./video_small/val/no_oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy0.mp4 from ./video_small/val/no_oops
# Deleted We're Back! Fails of the Week (May 2019) _ FailArmy15.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)84.mp4 from ./video_small/val/no_oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)68.mp4 from ./video_small/val/no_oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy42.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)73.mp4 from ./video_small/val/no_oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy19.mp4 from ./video_small/val/no_oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy10.mp4 from ./video_small/val/no_oops
# Deleted Fails at Home - Home Is Where The Fail Is (May 2018) _ FailArmy22.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy102.mp4 from ./video_small/val/no_oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy44.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Say It, Don't Spray It (Ep. 7)105.mp4 from ./video_small/val/no_oops
# Deleted Guess it's Time to Leave - Throwback Thursday (October 2017) _ FailArmy41.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Month (December 2016) _ FailArmy51.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)79.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy126.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy8.mp4 from ./video_small/val/no_oops
# Deleted Expensive Fails - That's Going To Cost You! (July 2017)1.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Say It, Don't Spray It (Ep. 7)34.mp4 from ./video_small/val/no_oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy20.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy85.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy46.mp4 from ./video_small/val/no_oops
# Deleted Best Fails of the Week 2 March 2016 _ 'I Think We Got What We're Looking For' by FailArmy31.mp4 from ./video_small/val/no_oops
# Deleted Recording for Duty - I’m So Confused (March 2019) _ FailArmy16.mp4 from ./video_small/val/no_oops
# Deleted Don't Rock the Boat - Throwback Fails (July 2017)70.mp4 from ./video_small/val/no_oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy101.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)83.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy21.mp4 from ./video_small/val/no_oops
# Deleted Funny Kid Fails (February 2016) _ FailArmy27.mp4 from ./video_small/val/no_oops
# Deleted Throwback Fails - That's one greedy cat!103.mp4 from ./video_small/val/no_oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy47.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)51.mp4 from ./video_small/val/no_oops
# Deleted 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)3.mp4 from ./video_small/val/no_oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy115.mp4 from ./video_small/val/no_oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy27.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)55.mp4 from ./video_small/val/no_oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)59.mp4 from ./video_small/val/no_oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)39.mp4 from ./video_small/val/no_oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy158.mp4 from ./video_small/val/no_oops
# Deleted Fails of the Week (March 2017) _ FailArmy39.mp4 from ./video_small/val/no_oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy250.mp4 from ./video_small/val/oops
# Deleted 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)14.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)72.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)73.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)11.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy94.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Stuck The Landing!! _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy23.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy34.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy169.mp4 from ./video_small/val/oops
# Deleted Fails of the Month (December 2016) _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - That's one greedy cat!42.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy42.mp4 from ./video_small/val/oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy45.mp4 from ./video_small/val/oops
# Deleted Hilarious Science Fails (July 2017) _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy20.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)105.mp4 from ./video_small/val/oops
# Deleted We're Back! Fails of the Week (May 2019) _ FailArmy16.mp4 from ./video_small/val/oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted Fails of the Week (March 2017) _ FailArmy8.mp4 from ./video_small/val/oops
# Deleted Hopeless Romantic - Fails of the Week (October 2018) _ FailArmy25.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy100.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)20.mp4 from ./video_small/val/oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy59.mp4 from ./video_small/val/oops
# Deleted Grandmas vs Grandpas - FailArmy Versus (December 2017) _ FailArmy27.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)81.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)34.mp4 from ./video_small/val/oops
# Deleted Anger Management - Fails of the Week (January 2019) _ FailArmy14.mp4 from ./video_small/val/oops
# Deleted Are You Serious! - Throwback Thursday (September 2017) _ FailArmy73.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)24.mp4 from ./video_small/val/oops
# Deleted FailArmy's Got Talent (October 2017) _ FailArmy4.mp4 from ./video_small/val/oops
# Deleted FailArmy's Got Talent (October 2017) _ FailArmy35.mp4 from ./video_small/val/oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)164.mp4 from ./video_small/val/oops
# Deleted 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)12.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy86.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted Grandmas vs Grandpas - FailArmy Versus (December 2017) _ FailArmy11.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy21.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)41.mp4 from ./video_small/val/oops
# Deleted Treadmill Terror - Fails of the Week (November 2018) _ FailArmy11.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy90.mp4 from ./video_small/val/oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy13.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week - Watch It Drones! (May 2018) _ FailArmy0.mp4 from ./video_small/val/oops
# Deleted FailArmy's Got Talent (October 2017) _ FailArmy5.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy13.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)74.mp4 from ./video_small/val/oops
# Deleted Confidence is Key - Fails of the Week (December 2016) _ FailArmy15.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)55.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week 3 February 2016 _ 'I'm OK, Wheres my Jetski!'FailArmy20.mp4 from ./video_small/val/oops
# Deleted Mirror Fight Back - Fails of the Week (November 2017) _ FailArmy16.mp4 from ./video_small/val/oops
# Deleted Rapper Slips off the Stage!! - Fails of the Week (July 2017)34.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)7.mp4 from ./video_small/val/oops
# Deleted Guess it's Time to Leave - Throwback Thursday (October 2017) _ FailArmy75.mp4 from ./video_small/val/oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted Funny Animal Fails - Just In Time For Election 2016 _ Fail Army11.mp4 from ./video_small/val/oops
# Deleted Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy12.mp4 from ./video_small/val/oops
# Deleted Fails of the Week (March 2017) _ FailArmy7.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy4.mp4 from ./video_small/val/oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy9.mp4 from ./video_small/val/oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy25.mp4 from ./video_small/val/oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy40.mp4 from ./video_small/val/oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)12.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Jump Around! (March 2018) _ FailArmy41.mp4 from ./video_small/val/oops
# Deleted Classic Redneck Waterslide - Throwback Fails (July 2017)23.mp4 from ./video_small/val/oops
# Deleted Confidence is Key - Fails of the Week (December 2016) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Backflip Belly Flops Optional! (December 2017) _ FailArmy13.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy91.mp4 from ./video_small/val/oops
# Deleted Workout Fails - New Year, Same Me (January 2017) _ FailArmy14.mp4 from ./video_small/val/oops
# Deleted Workout Fails - New Year, Same Me (January 2017) _ FailArmy19.mp4 from ./video_small/val/oops
# Deleted FailFactory - No Pain, No Gain (Workout Fails)146.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Saved It! (January 2018) _ FailArmy14.mp4 from ./video_small/val/oops
# Deleted Hilarious Holiday Fails (December 2017) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week - Watch It Drones! (May 2018) _ FailArmy24.mp4 from ./video_small/val/oops
# Deleted On The Job Fails - I Need A New Job (October 2017) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted Mirror Fight Back - Fails of the Week (November 2017) _ FailArmy37.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - That's one greedy cat!105.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy170.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy16.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy28.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Stuck The Landing!! _ FailArmy32.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - That's Got to Sting (Ep. 6)2.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Carriage Carnage (April 2018) _ FailArmy42.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy53.mp4 from ./video_small/val/oops
# Deleted Field Goal Fail - Fails of the Week (January 2019)0.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failing into Summer like... (May 2017)15.mp4 from ./video_small/val/oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201627.mp4 from ./video_small/val/oops
# Deleted Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'54.mp4 from ./video_small/val/oops
# Deleted Fails of the Month (December 2016) _ FailArmy43.mp4 from ./video_small/val/oops
# Deleted Funny Animal Fails - Just In Time For Election 2016 _ Fail Army14.mp4 from ./video_small/val/oops
# Deleted We're Back! Fails of the Week (May 2019) _ FailArmy12.mp4 from ./video_small/val/oops
# Deleted Expensive Fails - That's Going To Cost You! (July 2017)2.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy30.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy168.mp4 from ./video_small/val/oops
# Deleted Bats & Balls Fail Compilation _ By FailArmy 201634.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)51.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failing into Summer like... (May 2017)32.mp4 from ./video_small/val/oops
# Deleted Don't Rock the Boat - Throwback Fails (July 2017)28.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy25.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)108.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)35.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Jump Around! (March 2018) _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy35.mp4 from ./video_small/val/oops
# Deleted Crack That Whip - Throwback Fails (July 2017)76.mp4 from ./video_small/val/oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy80.mp4 from ./video_small/val/oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy101.mp4 from ./video_small/val/oops
# Deleted Funny Tourist Fails (June 2017) _ FailArmy10.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy5.mp4 from ./video_small/val/oops
# Deleted Bee Keeper Business - Fails of the Week (November 2018) _ FailArmy9.mp4 from ./video_small/val/oops
# Deleted Fails of the Month (December 2016) _ FailArmy13.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week 3 May 2016 _ FailArmy65.mp4 from ./video_small/val/oops
# Deleted Crack That Whip - Throwback Fails (July 2017)47.mp4 from ./video_small/val/oops
# Deleted Rapper Slips off the Stage!! - Fails of the Week (July 2017)38.mp4 from ./video_small/val/oops
# Deleted 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)4.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failing into Summer like... (May 2017)38.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)0.mp4 from ./video_small/val/oops
# Deleted Don't Rock the Boat - Throwback Fails (July 2017)41.mp4 from ./video_small/val/oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy30.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy90.mp4 from ./video_small/val/oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)83.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)50.mp4 from ./video_small/val/oops
# Deleted Crack That Whip - Throwback Fails (July 2017)46.mp4 from ./video_small/val/oops
# Deleted Are You Serious! - Throwback Thursday (September 2017) _ FailArmy72.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Say It, Don't Spray It (Ep. 7)23.mp4 from ./video_small/val/oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)57.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy10.mp4 from ./video_small/val/oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy3.mp4 from ./video_small/val/oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)163.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - That's one greedy cat!10.mp4 from ./video_small/val/oops
# Deleted Lets Get Stoned - Rock Fails0.mp4 from ./video_small/val/oops
# Deleted Bats & Balls Fail Compilation _ By FailArmy 201647.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Say It, Don't Spray It (Ep. 7)31.mp4 from ./video_small/val/oops
# Deleted Funny Animal Fails - Just In Time For Election 2016 _ Fail Army10.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy18.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy101.mp4 from ./video_small/val/oops
# Deleted The Master Swordsmen - Fails You Missed #17 _ FailArmy87.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy29.mp4 from ./video_small/val/oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 20161.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy21.mp4 from ./video_small/val/oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy4.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Backflip Belly Flops Optional! (December 2017) _ FailArmy80.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy36.mp4 from ./video_small/val/oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy14.mp4 from ./video_small/val/oops
# Deleted I Am Stuck In This Car! - Fails You Missed #16 _ FailArmy68.mp4 from ./video_small/val/oops
# Deleted Crack That Whip - Throwback Fails (July 2017)94.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)13.mp4 from ./video_small/val/oops
# Deleted Whip It, Whip It Real Good - Fails of the Month (November 2017) _ FailArmy15.mp4 from ./video_small/val/oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)24.mp4 from ./video_small/val/oops
# Deleted Are You Serious! - Throwback Thursday (September 2017) _ FailArmy68.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week - The Eagles Are Champs!! (February 2018) _ FailArmy12.mp4 from ./video_small/val/oops
# Deleted Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'29.mp4 from ./video_small/val/oops
# Deleted Break Yourself - Fails of the Week (September 2017) _ FailArmy28.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy10.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failing into Summer like... (May 2017)37.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy33.mp4 from ./video_small/val/oops
# Deleted Fails of the Week 4 September 2016 _ FailArmy15.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy16.mp4 from ./video_small/val/oops
# Deleted Sister Fails _ Funny Sisters Fail Compilation By FailArmy 201649.mp4 from ./video_small/val/oops
# Deleted Confidence is Key - Fails of the Week (December 2016) _ FailArmy20.mp4 from ./video_small/val/oops
# Deleted Whip It, Whip It Real Good - Fails of the Month (November 2017) _ FailArmy0.mp4 from ./video_small/val/oops
# Deleted Break Yourself - Fails of the Week (September 2017) _ FailArmy30.mp4 from ./video_small/val/oops
# Deleted The Ultimate Funny Monkey Compilation _ Monkey Fails by FailArmy6.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy53.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Saved It! (January 2018) _ FailArmy42.mp4 from ./video_small/val/oops
# Deleted Funny Kid Fails (February 2016) _ FailArmy16.mp4 from ./video_small/val/oops
# Deleted Confidence is Key - Fails of the Week (December 2016) _ FailArmy31.mp4 from ./video_small/val/oops
# Deleted Confidence is Key - Fails of the Week (December 2016) _ FailArmy42.mp4 from ./video_small/val/oops
# Deleted Don't Rock the Boat - Throwback Fails (July 2017)14.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy34.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Everybody Sing!! (February 2018) _ FailArmy31.mp4 from ./video_small/val/oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy29.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy46.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Carriage Carnage (April 2018) _ FailArmy46.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)99.mp4 from ./video_small/val/oops
# Deleted FailFactory - Derpy Dogs (March 2019) _ FailArmy34.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Jump Around! (March 2018) _ FailArmy38.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)118.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - That's one greedy cat!59.mp4 from ./video_small/val/oops
# Deleted Hopeless Romantic - Fails of the Week (October 2018) _ FailArmy4.mp4 from ./video_small/val/oops
# Deleted Fails at Home - Home Is Where The Fail Is (May 2018) _ FailArmy3.mp4 from ./video_small/val/oops
# Deleted Workout Fails - New Year, Same Me (January 2017) _ FailArmy23.mp4 from ./video_small/val/oops
# Deleted Expensive Fails - That's Going To Cost You! (July 2017)15.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)66.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy41.mp4 from ./video_small/val/oops
# Deleted Bats & Balls Fail Compilation _ By FailArmy 201651.mp4 from ./video_small/val/oops
# Deleted FailFactory - No Pain, No Gain (Workout Fails)121.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy39.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy41.mp4 from ./video_small/val/oops
# Deleted Sister Fails _ Funny Sisters Fail Compilation By FailArmy 20167.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)82.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)23.mp4 from ./video_small/val/oops
# Deleted Funny School Fails Compilation _ 'School's Out' By FailArmy 201629.mp4 from ./video_small/val/oops
# Deleted Funny School Fails Compilation _ 'School's Out' By FailArmy 201670.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Jump Around! (March 2018) _ FailArmy21.mp4 from ./video_small/val/oops
# Deleted Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy13.mp4 from ./video_small/val/oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)43.mp4 from ./video_small/val/oops
# Deleted Funny Kid Fails (February 2016) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)10.mp4 from ./video_small/val/oops
# Deleted Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'30.mp4 from ./video_small/val/oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy11.mp4 from ./video_small/val/oops
# Deleted The Wheels Are Coming Off! - Throwback Fails (December 2017) _ FailArmy0.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy180.mp4 from ./video_small/val/oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy7.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Carriage Carnage (April 2018) _ FailArmy49.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy102.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)22.mp4 from ./video_small/val/oops
# Deleted Fails of the Week - Insult to Injury (January 2017) _ FailArmy52.mp4 from ./video_small/val/oops
# Deleted Wheelie Gone Wrong - Fails of the Week (May 2018) _ FailArmy19.mp4 from ./video_small/val/oops
# Deleted FailFactory - No Pain, No Gain (Workout Fails)142.mp4 from ./video_small/val/oops
# Deleted Bats & Balls Fail Compilation _ By FailArmy 201622.mp4 from ./video_small/val/oops
# Deleted You've Got Bad Friends - Friendship Fails (September 2018) _ FailArmy33.mp4 from ./video_small/val/oops
# Deleted We're Back! Fails of the Week (May 2019) _ FailArmy10.mp4 from ./video_small/val/oops
# Deleted Whip It, Whip It Real Good - Fails of the Month (November 2017) _ FailArmy18.mp4 from ./video_small/val/oops
# Deleted Fails of the Week - Lookout for That Fence! (March 2017) _ FailArmy5.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy10.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy43.mp4 from ./video_small/val/oops
# Deleted That's A Sideways Wheelie! - Throwback Thursday (August 2017) _ FailArmy14.mp4 from ./video_small/val/oops
# Deleted Bee Keeper Business - Fails of the Week (November 2018) _ FailArmy6.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy45.mp4 from ./video_small/val/oops
# Deleted Are You Serious! - Throwback Thursday (September 2017) _ FailArmy71.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)83.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy3.mp4 from ./video_small/val/oops
# Deleted Funny Tourist Fails (June 2017) _ FailArmy35.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)15.mp4 from ./video_small/val/oops
# Deleted Fails of the Week 4 September 2016 _ FailArmy5.mp4 from ./video_small/val/oops
# Deleted I Made It! - Fails of the Week (October 2017) _ FailArmy34.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Party On!  (Ep. 3)52.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Backflip Belly Flops Optional! (December 2017) _ FailArmy11.mp4 from ./video_small/val/oops
# Deleted It's All Down Hill From Here - Throwback Fails (August 2017)82.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy80.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy193.mp4 from ./video_small/val/oops
# Deleted Rapper Slips off the Stage!! - Fails of the Week (July 2017)19.mp4 from ./video_small/val/oops
# Deleted Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'16.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week 3 February 2016 _ 'I'm OK, Wheres my Jetski!'FailArmy7.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Jump Around! (March 2018) _ FailArmy51.mp4 from ./video_small/val/oops
# Deleted Guess it's Time to Leave - Throwback Thursday (October 2017) _ FailArmy56.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy29.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy53.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy33.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy67.mp4 from ./video_small/val/oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)196.mp4 from ./video_small/val/oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy58.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Carriage Carnage (April 2018) _ FailArmy64.mp4 from ./video_small/val/oops
# Deleted Sister Fails _ Funny Sisters Fail Compilation By FailArmy 201614.mp4 from ./video_small/val/oops
# Deleted Father's Day Fails _ 'Dad Fails' By FailArmy 201629.mp4 from ./video_small/val/oops
# Deleted Bats & Balls Fail Compilation _ By FailArmy 201654.mp4 from ./video_small/val/oops
# Deleted Fails of the Week - Insult to Injury (January 2017) _ FailArmy26.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Failure In Full Force (January 2017) _ FailArmy0.mp4 from ./video_small/val/oops
# Deleted Funny School Fails Compilation _ 'School's Out' By FailArmy 20167.mp4 from ./video_small/val/oops
# Deleted Hilarious Science Fails (July 2017) _ FailArmy5.mp4 from ./video_small/val/oops
# Deleted You've Got Bad Friends - Friendship Fails (September 2018) _ FailArmy14.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week 3 February 2016 _ 'I'm OK, Wheres my Jetski!'FailArmy21.mp4 from ./video_small/val/oops
# Deleted Funny Kid Fails (February 2016) _ FailArmy15.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy85.mp4 from ./video_small/val/oops
# Deleted Mom's Going To Be Mad - Throwback Fails (June 2017) _ FailArmy64.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Carriage Carnage (April 2018) _ FailArmy21.mp4 from ./video_small/val/oops
# Deleted FailArmy Playlist - Inflatables and Big Ballers (March 2019) _ FailArmy225.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy12.mp4 from ./video_small/val/oops
# Deleted Funny Tourist Fails (June 2017) _ FailArmy4.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - That's one greedy cat!93.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)45.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - When Enough Is Enough! (February 2018) _ FailArmy55.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Saved It! (January 2018) _ FailArmy47.mp4 from ./video_small/val/oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy4.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)87.mp4 from ./video_small/val/oops
# Deleted Ninja Fails - Sweep The Leg! (March 2017) _ FailArmy30.mp4 from ./video_small/val/oops
# Deleted Funny Kid Fails (February 2016) _ FailArmy17.mp4 from ./video_small/val/oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)35.mp4 from ./video_small/val/oops
# Deleted Don't Get Zapped - Throwback Thursday (August 2017)49.mp4 from ./video_small/val/oops
# Deleted Classic Redneck Waterslide - Throwback Fails (July 2017)49.mp4 from ./video_small/val/oops
# Deleted Funny School Fails Compilation _ 'School's Out' By FailArmy 201687.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - That's Going To Cost You  (Ep. 10)104.mp4 from ./video_small/val/oops
# Deleted Are You Serious! - Throwback Thursday (September 2017) _ FailArmy74.mp4 from ./video_small/val/oops
# Deleted Fails of the Month - Stuck The Landing!! _ FailArmy11.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Saved It! (January 2018) _ FailArmy7.mp4 from ./video_small/val/oops
# Deleted Get Out Of The Way!! - FailArmy After Dark (Ep. 12)125.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Week 2 March 2016 _ 'I Think We Got What We're Looking For' by FailArmy54.mp4 from ./video_small/val/oops
# Deleted Classic bails and Throwback Fails (June 2017) _ FailArmy37.mp4 from ./video_small/val/oops
# Deleted 34 Funny Kid Nominees - FailArmy Hall Of Fame (May 2017)29.mp4 from ./video_small/val/oops
# Deleted Lets Get Stoned - Rock Fails12.mp4 from ./video_small/val/oops
# Deleted Snow Day Fails - It's Cold Out There! (January 2018) _ FailArmy45.mp4 from ./video_small/val/oops
# Deleted FailArmy After Dark - Does That Sheep Have Sunglasses  (Ep. 8)96.mp4 from ./video_small/val/oops
# Deleted Ultimate Parkour Fails Compilation Part 2 by FailArmy _ 'You Are The King Of Bails, Man.'35.mp4 from ./video_small/val/oops
# Deleted Fails of the Week - Insult to Injury (January 2017) _ FailArmy22.mp4 from ./video_small/val/oops
# Deleted Funny Animal Fails - Just In Time For Election 2016 _ Fail Army0.mp4 from ./video_small/val/oops
# Deleted Let's Get It!! - FailArmy After Dark (ep. 2)97.mp4 from ./video_small/val/oops
# Deleted Crack That Whip - Throwback Fails (July 2017)53.mp4 from ./video_small/val/oops
# Deleted Best Fails of the Year 2017 - Part 1 (December 2017) _ FailArmy12.mp4 from ./video_small/val/oops
# Deleted Throwback Fails - Jump Around! (March 2018) _ FailArmy13.mp4 from ./video_small/val/oops

# %%
# Update small_transition_times for train videos
update_small_transition_times(train_no_oops_folder, "train", "no_oops")
update_small_transition_times(train_oops_folder, "train", "oops")

# Update small_transition_times for val videos
update_small_transition_times(val_no_oops_folder, "val", "no_oops")
update_small_transition_times(val_oops_folder, "val", "oops")

# %%
print(len(small_transition_times))
# Out:
# 1255

# %%
output_json_path = "./video_small/smaller_transition_times.json"

output_directory = os.path.dirname(output_json_path)
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

with open(output_json_path, 'w', encoding='utf-8') as output_json_file:
    json.dump(small_transition_times, output_json_file, indent=4, ensure_ascii=False)

print("Small transition times JSON file saved successfully at:", output_json_path)
# Out:
# Small transition times JSON file saved successfully at: ./video_small/smaller_transition_times.json
